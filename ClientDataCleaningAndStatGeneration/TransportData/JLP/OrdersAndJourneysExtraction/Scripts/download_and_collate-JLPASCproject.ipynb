# %%
## pip install sharepy <- run this in python command line

# %%
########################################################
# Original Author: Prasanna Jagadeesan
# Created Date: 30/07/2019
# Modification Author: Ben Fletcher
# Modified Date: 30/10/2019
# Description: This program downloads Waitrose data from FPS SharePoint to local machine, extracts and 
# collates data, and uploads back to SharePoint
########################################################
import os
import pyodbc
import pandas as pd
from datetime import datetime
from os import walk

# %%
################################
# Function to run query in db
# Inputs: 
#       cnxn -> connection object to DB
#       query -> query string
#       params -> tuple of query parameters
# Output:
#       rows -> query result. Rows of data from DB
#################################
def run_query(cnxn,query,params):
    cursor = cnxn.cursor()
    cursor.execute(query,params)
    rows = []
    if "INSERT" not in query:
        rows = cursor.fetchall()
    return rows

# %%
################################
# Function to find index of cell (from excel data)
# where the value starts with "Total Route".
# This index will then be used to find the route
# data and order data which will be below the index found
# Inputs: 
#       data -> excel data
#       total_rows -> num. rows in excel
#       i,j -> starting position of excel cells
# Output:
#       i -> Row index of "Total Route"
#################################
def find_index_total_route(data,total_rows,i,j):
    found_total_route = False
    while not found_total_route:
        cell_value = str(data.iloc[i,j])
        if cell_value is not None:
            if cell_value.startswith("Total Route"):
                found_total_route = True
            else:
                i+=1
                if i > total_rows-1:
                    i = -1 # To identify end of row is reached
                    found_total_route = True
        else:
            i+=1
            if i > total_rows-1:
                i = -1 # To identify end of row is reached
                found_total_route = True
    return i

# %%
################################
# Function to find index (i,j) of cell (from excel data)
# where the value starts with "Branch".
#
# Inputs: 
#       data -> excel data
#       total_rows -> num. rows in excel
#       i,j -> starting position of excel cells
# Output:
#       (i,j) -> Tuple index of "Branch"
#################################        
def find_index_branch_id(data,total_rows,i,j):
    found_branch_id = False
    return_param = ()
    while not found_branch_id:
        cell_value = str(data.iloc[i,j])
        if cell_value is not None:
            if cell_value.startswith("Branch"):
                found_branch_id = True
                return_param = (i,j)
            else:
                j+=1
                if j >= 38:
                    j = 3
                    i+=1
                    if i > total_rows-1:
                        found_branch_id = True
                        return_param = (-1,-1)
        else:
            j+=1
            if j >= 38:
                j = 3
                i+=1
                if i > total_rows-1:
                    found_branch_id = True
                    return_param = (-1,-1)
                    
    return return_param

# %%
################################
# Function to read the route data with given 
# starting (i,j) positions
#
# Inputs: 
#       data -> excel data
#       total_rows -> num. rows in excel
#       i,j -> starting position of excel cells
# Output:
#       [] -> List of parameters
################################# 
def read_rest_of_route_data(data,total_rows,i,j):
    return_param = []
    # Waitrose uses template and the number of columns of route data 
    # is always 38. Hence looping through 28 columns and fetching route data
    while j <= 38:
        cell_value = data.iloc[i,j]
        if cell_value is not None:            
            return_param.append(cell_value)
        j+=1

    return return_param

# %%
################################
# After finding index of "Total Route", usually the cell
# below "Total Route" is the route_id index. This function
# will get the route_id index
# Inputs: 
#       data -> excel data
#       total_rows -> num. rows in excel
#       i,j -> starting position of excel cells
# Output:
#       i -> Row index of "Route ID"
#################################
def find_route_id_index(data,total_rows,i,j):
    found_route_id_index = False
    while not found_route_id_index:
        try:
            cell_value = data.iloc[i,j]
            if cell_value is None:
                i+=1
            else:
                cell_value = int(cell_value)
                found_route_id_index = True
        except ValueError:
            i+=1
            if i > total_rows-1:
                i = -1
                found_route_id_index = True
            pass

    return i

# %%
################################
# For the given value this function 
# tries to get date. If not it returns
# "None" value
################################
def get_date(val):
    date_val = None

    if type(val) is str:
        date_val = datetime.strptime(val,"%d/%m/%Y")
    else:
        date_val = val

    return date_val

# %%
################################
# For the given value this function 
# tries to get time. If not it returns
# "None" value
################################
def get_time(val):
    time_val = None
    
    if type(val) is str:
        time_val = datetime.strptime(val,"%H:%M:%S")        
    else:
        time_val = val

    return time_val

# %%
################################
# For the given value this function 
# tries to get percentage value if
# the input value is a string (e.g. '85%')
# If not it returns "None" value
################################
def get_percentage(val):
    percentage_val = None
    try:
        percentage_val = float(val)
    except:
        percentage_val = val[:-1] # From input value (e.g. '85%'), removes percentage
        percentage_val = percentage_val.replace(",","") # Found some percentage string values with ",". Just removing them
        percentage_val = float(percentage_val) / 100

    return percentage_val

# %%
################################
# For the given value this function 
# tries to get int value. If not it 
# returns 0
################################
def get_int(val):
    if not val or val is None:
        return 0
    else:
        return int(val)

# %%
################################
# For the given value this function 
# tries to get float value. If not it 
# returns 0
################################
def get_float(val):
    if not val or val is None:
        return 0
    else:
        return float(val)

# %%
import sharepy
import json
import time




sharepoint_site = "flexpowerltd.sharepoint.com"

raw_data_folder = "raw_data_07022020"

# Parent directory of all files
xlsx_files_root_dir = "C:/Users/benfl/OneDrive - Flexible Power Systems Ltd/Documents/Python Scripts/Waitrose Collation"

filename_loc = 12

# (1) Authenticate
s = sharepy.connect(sharepoint_site)
# Out:
# Enter your username: ben.fletcher@flexpowerltd.com
# Enter your password: ········
# Authentication successful

# %%
# first data batch

t1 = time.process_time()

r = s.get("https://flexpowerltd.sharepoint.com/sites/JLP-FPSProject/_api/web\
/GetFolderByServerRelativeUrl('/sites/JLP-FPSProject/Shared Documents\
/Waitrose Data Transfer ALL')/Files")
data = r.json()
for i in range(0, len(data['d']['results'])):
    file_sp_path = str(data['d']['results'][i]['__metadata']['id'])
    path_split = file_sp_path.split('/')
    filename = path_split[filename_loc]
    filename = filename.replace('\')', '')
    
    # (3) Download file
    # DO NOT INDENT BELOW LINES (ANY INDENTATION WILL BE INCLUDED IN STRING)
    r = s.getfile("https://flexpowerltd.sharepoint.com/sites/JLP-FPSProject/_api/web\
/GetFileByServerRelativeUrl('/sites/JLP-FPSProject/Shared Documents\
/Waitrose Data Transfer ALL/" + filename + "')/$value"\
    , filename = raw_data_folder + "/" + filename)

    print("Downloaded ", i+1, "/", len(data['d']['results']))
t2 = time.process_time()
t3 = t2-t1
print('download files: t3 = ', t3)
# Out:
# Downloaded  1 / 778
# Downloaded  2 / 778
# Downloaded  3 / 778
# Downloaded  4 / 778
# Downloaded  5 / 778
# Downloaded  6 / 778
# Downloaded  7 / 778
# Downloaded  8 / 778
# Downloaded  9 / 778
# Downloaded  10 / 778
# Downloaded  11 / 778
# Downloaded  12 / 778
# Downloaded  13 / 778
# Downloaded  14 / 778
# Downloaded  15 / 778
# Downloaded  16 / 778
# Downloaded  17 / 778
# Downloaded  18 / 778
# Downloaded  19 / 778
# Downloaded  20 / 778
# Downloaded  21 / 778
# Downloaded  22 / 778
# Downloaded  23 / 778
# Downloaded  24 / 778
# Downloaded  25 / 778
# Downloaded  26 / 778
# Downloaded  27 / 778
# Downloaded  28 / 778
# Downloaded  29 / 778
# Downloaded  30 / 778
# Downloaded  31 / 778
# Downloaded  32 / 778
# Downloaded  33 / 778
# Downloaded  34 / 778
# Downloaded  35 / 778
# Downloaded  36 / 778
# Downloaded  37 / 778
# Downloaded  38 / 778
# Downloaded  39 / 778
# Downloaded  40 / 778
# Downloaded  41 / 778
# Downloaded  42 / 778
# Downloaded  43 / 778
# Downloaded  44 / 778
# Downloaded  45 / 778
# Downloaded  46 / 778
# Downloaded  47 / 778
# Downloaded  48 / 778
# Downloaded  49 / 778
# Downloaded  50 / 778
# Downloaded  51 / 778
# Downloaded  52 / 778
# Downloaded  53 / 778
# Downloaded  54 / 778
# Downloaded  55 / 778
# Downloaded  56 / 778
# Downloaded  57 / 778
# Downloaded  58 / 778
# Downloaded  59 / 778
# Downloaded  60 / 778
# Downloaded  61 / 778
# Downloaded  62 / 778
# Downloaded  63 / 778
# Downloaded  64 / 778
# Downloaded  65 / 778
# Downloaded  66 / 778
# Downloaded  67 / 778
# Downloaded  68 / 778
# Downloaded  69 / 778
# Downloaded  70 / 778
# Downloaded  71 / 778
# Downloaded  72 / 778
# Downloaded  73 / 778
# Downloaded  74 / 778
# Downloaded  75 / 778
# Downloaded  76 / 778
# Downloaded  77 / 778
# Downloaded  78 / 778
# Downloaded  79 / 778
# Downloaded  80 / 778
# Downloaded  81 / 778
# Downloaded  82 / 778
# Downloaded  83 / 778
# Downloaded  84 / 778
# Downloaded  85 / 778
# Downloaded  86 / 778
# Downloaded  87 / 778
# Downloaded  88 / 778
# Downloaded  89 / 778
# Downloaded  90 / 778
# Downloaded  91 / 778
# Downloaded  92 / 778
# Downloaded  93 / 778
# Downloaded  94 / 778
# Downloaded  95 / 778
# Downloaded  96 / 778
# Downloaded  97 / 778
# Downloaded  98 / 778
# Downloaded  99 / 778
# Downloaded  100 / 778
# Downloaded  101 / 778
# Downloaded  102 / 778
# Downloaded  103 / 778
# Downloaded  104 / 778
# Downloaded  105 / 778
# Downloaded  106 / 778
# Downloaded  107 / 778
# Downloaded  108 / 778
# Downloaded  109 / 778
# Downloaded  110 / 778
# Downloaded  111 / 778
# Downloaded  112 / 778
# Downloaded  113 / 778
# Downloaded  114 / 778
# Downloaded  115 / 778
# Downloaded  116 / 778
# Downloaded  117 / 778
# Downloaded  118 / 778
# Downloaded  119 / 778
# Downloaded  120 / 778
# Downloaded  121 / 778
# Downloaded  122 / 778
# Downloaded  123 / 778
# Downloaded  124 / 778
# Downloaded  125 / 778
# Downloaded  126 / 778
# Downloaded  127 / 778
# Downloaded  128 / 778
# Downloaded  129 / 778
# Downloaded  130 / 778
# Downloaded  131 / 778
# Downloaded  132 / 778
# Downloaded  133 / 778
# Downloaded  134 / 778
# Downloaded  135 / 778
# Downloaded  136 / 778
# Downloaded  137 / 778
# Downloaded  138 / 778
# Downloaded  139 / 778
# Downloaded  140 / 778
# Downloaded  141 / 778
# Downloaded  142 / 778
# Downloaded  143 / 778
# Downloaded  144 / 778
# Downloaded  145 / 778
# Downloaded  146 / 778
# Downloaded  147 / 778
# Downloaded  148 / 778
# Downloaded  149 / 778
# Downloaded  150 / 778
# Downloaded  151 / 778
# Downloaded  152 / 778
# Downloaded  153 / 778
# Downloaded  154 / 778
# Downloaded  155 / 778
# Downloaded  156 / 778
# Downloaded  157 / 778
# Downloaded  158 / 778
# Downloaded  159 / 778
# Downloaded  160 / 778
# Downloaded  161 / 778
# Downloaded  162 / 778
# Downloaded  163 / 778
# Downloaded  164 / 778
# Downloaded  165 / 778
# Downloaded  166 / 778
# Downloaded  167 / 778
# Downloaded  168 / 778
# Downloaded  169 / 778
# Downloaded  170 / 778
# Downloaded  171 / 778
# Downloaded  172 / 778
# Downloaded  173 / 778
# Downloaded  174 / 778
# Downloaded  175 / 778
# Downloaded  176 / 778
# Downloaded  177 / 778
# Downloaded  178 / 778
# Downloaded  179 / 778
# Downloaded  180 / 778
# Downloaded  181 / 778
# Downloaded  182 / 778
# Downloaded  183 / 778
# Downloaded  184 / 778
# Downloaded  185 / 778
# Downloaded  186 / 778
# Downloaded  187 / 778
# Downloaded  188 / 778
# Downloaded  189 / 778
# Downloaded  190 / 778
# Downloaded  191 / 778
# Downloaded  192 / 778
# Downloaded  193 / 778
# Downloaded  194 / 778
# Downloaded  195 / 778
# Downloaded  196 / 778
# Downloaded  197 / 778
# Downloaded  198 / 778
# Downloaded  199 / 778
# Downloaded  200 / 778
# Downloaded  201 / 778
# Downloaded  202 / 778
# Downloaded  203 / 778
# Downloaded  204 / 778
# Downloaded  205 / 778
# Downloaded  206 / 778
# Downloaded  207 / 778
# Downloaded  208 / 778
# Downloaded  209 / 778
# Downloaded  210 / 778
# Downloaded  211 / 778
# Downloaded  212 / 778
# Downloaded  213 / 778
# Downloaded  214 / 778
# Downloaded  215 / 778
# Downloaded  216 / 778
# Downloaded  217 / 778
# Downloaded  218 / 778
# Downloaded  219 / 778
# Downloaded  220 / 778
# Downloaded  221 / 778
# Downloaded  222 / 778
# Downloaded  223 / 778
# Downloaded  224 / 778
# Downloaded  225 / 778
# Downloaded  226 / 778
# Downloaded  227 / 778
# Downloaded  228 / 778
# Downloaded  229 / 778
# Downloaded  230 / 778
# Downloaded  231 / 778
# Downloaded  232 / 778
# Downloaded  233 / 778
# Downloaded  234 / 778
# Downloaded  235 / 778
# Downloaded  236 / 778
# Downloaded  237 / 778
# Downloaded  238 / 778
# Downloaded  239 / 778
# Downloaded  240 / 778
# Downloaded  241 / 778
# Downloaded  242 / 778
# Downloaded  243 / 778
# Downloaded  244 / 778
# Downloaded  245 / 778
# Downloaded  246 / 778
# Downloaded  247 / 778
# Downloaded  248 / 778
# Downloaded  249 / 778
# Downloaded  250 / 778
# Downloaded  251 / 778
# Downloaded  252 / 778
# Downloaded  253 / 778
# Downloaded  254 / 778
# Downloaded  255 / 778
# Downloaded  256 / 778
# Downloaded  257 / 778
# Downloaded  258 / 778
# Downloaded  259 / 778
# Downloaded  260 / 778
# Downloaded  261 / 778
# Downloaded  262 / 778
# Downloaded  263 / 778
# Downloaded  264 / 778
# Downloaded  265 / 778
# Downloaded  266 / 778
# Downloaded  267 / 778
# Downloaded  268 / 778
# Downloaded  269 / 778
# Downloaded  270 / 778
# Downloaded  271 / 778
# Downloaded  272 / 778
# Downloaded  273 / 778
# Downloaded  274 / 778
# Downloaded  275 / 778
# Downloaded  276 / 778
# Downloaded  277 / 778
# Downloaded  278 / 778
# Downloaded  279 / 778
# Downloaded  280 / 778
# Downloaded  281 / 778
# Downloaded  282 / 778
# Downloaded  283 / 778
# Downloaded  284 / 778
# Downloaded  285 / 778
# Downloaded  286 / 778
# Downloaded  287 / 778
# Downloaded  288 / 778
# Downloaded  289 / 778
# Downloaded  290 / 778
# Downloaded  291 / 778
# Downloaded  292 / 778
# Downloaded  293 / 778
# Downloaded  294 / 778
# Downloaded  295 / 778
# Downloaded  296 / 778
# Downloaded  297 / 778
# Downloaded  298 / 778
# Downloaded  299 / 778
# Downloaded  300 / 778
# Downloaded  301 / 778
# Downloaded  302 / 778
# Downloaded  303 / 778
# Downloaded  304 / 778
# Downloaded  305 / 778
# Downloaded  306 / 778
# Downloaded  307 / 778
# Downloaded  308 / 778
# Downloaded  309 / 778
# Downloaded  310 / 778
# Downloaded  311 / 778
# Downloaded  312 / 778
# Downloaded  313 / 778
# Downloaded  314 / 778
# Downloaded  315 / 778
# Downloaded  316 / 778
# Downloaded  317 / 778
# Downloaded  318 / 778
# Downloaded  319 / 778
# Downloaded  320 / 778
# Downloaded  321 / 778
# Downloaded  322 / 778
# Downloaded  323 / 778
# Downloaded  324 / 778
# Downloaded  325 / 778
# Downloaded  326 / 778
# Downloaded  327 / 778
# Downloaded  328 / 778
# Downloaded  329 / 778
# Downloaded  330 / 778
# Downloaded  331 / 778
# Downloaded  332 / 778
# Downloaded  333 / 778
# Downloaded  334 / 778
# Downloaded  335 / 778
# Downloaded  336 / 778
# Downloaded  337 / 778
# Downloaded  338 / 778
# Downloaded  339 / 778
# Downloaded  340 / 778
# Downloaded  341 / 778
# Downloaded  342 / 778
# Downloaded  343 / 778
# Downloaded  344 / 778
# Downloaded  345 / 778
# Downloaded  346 / 778
# Downloaded  347 / 778
# Downloaded  348 / 778
# Downloaded  349 / 778
# Downloaded  350 / 778
# Downloaded  351 / 778
# Downloaded  352 / 778
# Downloaded  353 / 778
# Downloaded  354 / 778
# Downloaded  355 / 778
# Downloaded  356 / 778
# Downloaded  357 / 778
# Downloaded  358 / 778
# Downloaded  359 / 778
# Downloaded  360 / 778
# Downloaded  361 / 778
# Downloaded  362 / 778
# Downloaded  363 / 778
# Downloaded  364 / 778
# Downloaded  365 / 778
# Downloaded  366 / 778
# Downloaded  367 / 778
# Downloaded  368 / 778
# Downloaded  369 / 778
# Downloaded  370 / 778
# Downloaded  371 / 778
# Downloaded  372 / 778
# Downloaded  373 / 778
# Downloaded  374 / 778
# Downloaded  375 / 778
# Downloaded  376 / 778
# Downloaded  377 / 778
# Downloaded  378 / 778
# Downloaded  379 / 778
# Downloaded  380 / 778
# Downloaded  381 / 778
# Downloaded  382 / 778
# Downloaded  383 / 778
# Downloaded  384 / 778
# Downloaded  385 / 778
# Downloaded  386 / 778
# Downloaded  387 / 778
# Downloaded  388 / 778
# Downloaded  389 / 778
# Downloaded  390 / 778
# Downloaded  391 / 778
# Downloaded  392 / 778
# Downloaded  393 / 778
# Downloaded  394 / 778
# Downloaded  395 / 778
# Downloaded  396 / 778
# Downloaded  397 / 778
# Downloaded  398 / 778
# Downloaded  399 / 778
# Downloaded  400 / 778
# Downloaded  401 / 778
# Downloaded  402 / 778
# Downloaded  403 / 778
# Downloaded  404 / 778
# Downloaded  405 / 778
# Downloaded  406 / 778
# Downloaded  407 / 778
# Downloaded  408 / 778
# Downloaded  409 / 778
# Downloaded  410 / 778
# Downloaded  411 / 778
# Downloaded  412 / 778
# Downloaded  413 / 778
# Downloaded  414 / 778
# Downloaded  415 / 778
# Downloaded  416 / 778
# Downloaded  417 / 778
# Downloaded  418 / 778
# Downloaded  419 / 778
# Downloaded  420 / 778
# Downloaded  421 / 778
# Downloaded  422 / 778
# Downloaded  423 / 778
# Downloaded  424 / 778
# Downloaded  425 / 778
# Downloaded  426 / 778
# Downloaded  427 / 778
# Downloaded  428 / 778
# Downloaded  429 / 778
# Downloaded  430 / 778
# Downloaded  431 / 778
# Downloaded  432 / 778
# Downloaded  433 / 778
# Downloaded  434 / 778
# Downloaded  435 / 778
# Downloaded  436 / 778
# Downloaded  437 / 778
# Downloaded  438 / 778
# Downloaded  439 / 778
# Downloaded  440 / 778
# Downloaded  441 / 778
# Downloaded  442 / 778
# Downloaded  443 / 778
# Downloaded  444 / 778
# Downloaded  445 / 778
# Downloaded  446 / 778
# Downloaded  447 / 778
# Downloaded  448 / 778
# Downloaded  449 / 778
# Downloaded  450 / 778
# Downloaded  451 / 778
# Downloaded  452 / 778
# Downloaded  453 / 778
# Downloaded  454 / 778
# Downloaded  455 / 778
# Downloaded  456 / 778
# Downloaded  457 / 778
# Downloaded  458 / 778
# Downloaded  459 / 778
# Downloaded  460 / 778
# Downloaded  461 / 778
# Downloaded  462 / 778
# Downloaded  463 / 778
# Downloaded  464 / 778
# Downloaded  465 / 778
# Downloaded  466 / 778
# Downloaded  467 / 778
# Downloaded  468 / 778
# Downloaded  469 / 778
# Downloaded  470 / 778
# Downloaded  471 / 778
# Downloaded  472 / 778
# Downloaded  473 / 778
# Downloaded  474 / 778
# Downloaded  475 / 778
# Downloaded  476 / 778
# Downloaded  477 / 778
# Downloaded  478 / 778
# Downloaded  479 / 778
# Downloaded  480 / 778
# Downloaded  481 / 778
# Downloaded  482 / 778
# Downloaded  483 / 778
# Downloaded  484 / 778
# Downloaded  485 / 778
# Downloaded  486 / 778
# Downloaded  487 / 778
# Downloaded  488 / 778
# Downloaded  489 / 778
# Downloaded  490 / 778
# Downloaded  491 / 778
# Downloaded  492 / 778
# Downloaded  493 / 778
# Downloaded  494 / 778
# Downloaded  495 / 778
# Downloaded  496 / 778
# Downloaded  497 / 778
# Downloaded  498 / 778
# Downloaded  499 / 778
# Downloaded  500 / 778
# Downloaded  501 / 778
# Downloaded  502 / 778
# Downloaded  503 / 778
# Downloaded  504 / 778
# Downloaded  505 / 778
# Downloaded  506 / 778
# Downloaded  507 / 778
# Downloaded  508 / 778
# Downloaded  509 / 778
# Downloaded  510 / 778
# Downloaded  511 / 778
# Downloaded  512 / 778
# Downloaded  513 / 778
# Downloaded  514 / 778
# Downloaded  515 / 778
# Downloaded  516 / 778
# Downloaded  517 / 778
# Downloaded  518 / 778
# Downloaded  519 / 778
# Downloaded  520 / 778
# Downloaded  521 / 778
# Downloaded  522 / 778
# Downloaded  523 / 778
# Downloaded  524 / 778
# Downloaded  525 / 778
# Downloaded  526 / 778
# Downloaded  527 / 778
# Downloaded  528 / 778
# Downloaded  529 / 778
# Downloaded  530 / 778
# Downloaded  531 / 778
# Downloaded  532 / 778
# Downloaded  533 / 778
# Downloaded  534 / 778
# Downloaded  535 / 778
# Downloaded  536 / 778
# Downloaded  537 / 778
# Downloaded  538 / 778
# Downloaded  539 / 778
# Downloaded  540 / 778
# Downloaded  541 / 778
# Downloaded  542 / 778
# Downloaded  543 / 778
# Downloaded  544 / 778
# Downloaded  545 / 778
# Downloaded  546 / 778
# Downloaded  547 / 778
# Downloaded  548 / 778
# Downloaded  549 / 778
# Downloaded  550 / 778
# Downloaded  551 / 778
# Downloaded  552 / 778
# Downloaded  553 / 778
# Downloaded  554 / 778
# Downloaded  555 / 778
# Downloaded  556 / 778
# Downloaded  557 / 778
# Downloaded  558 / 778
# Downloaded  559 / 778
# Downloaded  560 / 778
# Downloaded  561 / 778
# Downloaded  562 / 778
# Downloaded  563 / 778
# Downloaded  564 / 778
# Downloaded  565 / 778
# Downloaded  566 / 778
# Downloaded  567 / 778
# Downloaded  568 / 778
# Downloaded  569 / 778
# Downloaded  570 / 778
# Downloaded  571 / 778
# Downloaded  572 / 778
# Downloaded  573 / 778
# Downloaded  574 / 778
# Downloaded  575 / 778
# Downloaded  576 / 778
# Downloaded  577 / 778
# Downloaded  578 / 778
# Downloaded  579 / 778
# Downloaded  580 / 778
# Downloaded  581 / 778
# Downloaded  582 / 778
# Downloaded  583 / 778
# Downloaded  584 / 778
# Downloaded  585 / 778
# Downloaded  586 / 778
# Downloaded  587 / 778
# Downloaded  588 / 778
# Downloaded  589 / 778
# Downloaded  590 / 778
# Downloaded  591 / 778
# Downloaded  592 / 778
# Downloaded  593 / 778
# Downloaded  594 / 778
# Downloaded  595 / 778
# Downloaded  596 / 778
# Downloaded  597 / 778
# Downloaded  598 / 778
# Downloaded  599 / 778
# Downloaded  600 / 778
# Downloaded  601 / 778
# Downloaded  602 / 778
# Downloaded  603 / 778
# Downloaded  604 / 778
# Downloaded  605 / 778
# Downloaded  606 / 778
# Downloaded  607 / 778
# Downloaded  608 / 778
# Downloaded  609 / 778
# Downloaded  610 / 778
# Downloaded  611 / 778
# Downloaded  612 / 778
# Downloaded  613 / 778
# Downloaded  614 / 778
# Downloaded  615 / 778
# Downloaded  616 / 778
# Downloaded  617 / 778
# Downloaded  618 / 778
# Downloaded  619 / 778
# Downloaded  620 / 778
# Downloaded  621 / 778
# Downloaded  622 / 778
# Downloaded  623 / 778
# Downloaded  624 / 778
# Downloaded  625 / 778
# Downloaded  626 / 778
# Downloaded  627 / 778
# Downloaded  628 / 778
# Downloaded  629 / 778
# Downloaded  630 / 778
# Downloaded  631 / 778
# Downloaded  632 / 778
# Downloaded  633 / 778
# Downloaded  634 / 778
# Downloaded  635 / 778
# Downloaded  636 / 778
# Downloaded  637 / 778
# Downloaded  638 / 778
# Downloaded  639 / 778
# Downloaded  640 / 778
# Downloaded  641 / 778
# Downloaded  642 / 778
# Downloaded  643 / 778
# Downloaded  644 / 778
# Downloaded  645 / 778
# Downloaded  646 / 778
# Downloaded  647 / 778
# Downloaded  648 / 778
# Downloaded  649 / 778
# Downloaded  650 / 778
# Downloaded  651 / 778
# Downloaded  652 / 778
# Downloaded  653 / 778
# Downloaded  654 / 778
# Downloaded  655 / 778
# Downloaded  656 / 778
# Downloaded  657 / 778
# Downloaded  658 / 778
# Downloaded  659 / 778
# Downloaded  660 / 778
# Downloaded  661 / 778
# Downloaded  662 / 778
# Downloaded  663 / 778
# Downloaded  664 / 778
# Downloaded  665 / 778
# Downloaded  666 / 778
# Downloaded  667 / 778
# Downloaded  668 / 778
# Downloaded  669 / 778
# Downloaded  670 / 778
# Downloaded  671 / 778
# Downloaded  672 / 778
# Downloaded  673 / 778
# Downloaded  674 / 778
# Downloaded  675 / 778
# Downloaded  676 / 778
# Downloaded  677 / 778
# Downloaded  678 / 778
# Downloaded  679 / 778
# Downloaded  680 / 778
# Downloaded  681 / 778
# Downloaded  682 / 778
# Downloaded  683 / 778
# Downloaded  684 / 778
# Downloaded  685 / 778
# Downloaded  686 / 778
# Downloaded  687 / 778
# Downloaded  688 / 778
# Downloaded  689 / 778
# Downloaded  690 / 778
# Downloaded  691 / 778
# Downloaded  692 / 778
# Downloaded  693 / 778
# Downloaded  694 / 778
# Downloaded  695 / 778
# Downloaded  696 / 778
# Downloaded  697 / 778
# Downloaded  698 / 778
# Downloaded  699 / 778
# Downloaded  700 / 778
# Downloaded  701 / 778
# Downloaded  702 / 778
# Downloaded  703 / 778
# Downloaded  704 / 778
# Downloaded  705 / 778
# Downloaded  706 / 778
# Downloaded  707 / 778
# Downloaded  708 / 778
# Downloaded  709 / 778
# Downloaded  710 / 778
# Downloaded  711 / 778
# Downloaded  712 / 778
# Downloaded  713 / 778
# Downloaded  714 / 778
# Downloaded  715 / 778
# Downloaded  716 / 778
# Downloaded  717 / 778
# Downloaded  718 / 778
# Downloaded  719 / 778
# Downloaded  720 / 778
# Downloaded  721 / 778
# Downloaded  722 / 778
# Downloaded  723 / 778
# Downloaded  724 / 778
# Downloaded  725 / 778
# Downloaded  726 / 778
# Downloaded  727 / 778
# Downloaded  728 / 778
# Downloaded  729 / 778
# Downloaded  730 / 778
# Downloaded  731 / 778
# Downloaded  732 / 778
# Downloaded  733 / 778
# Downloaded  734 / 778
# Downloaded  735 / 778
# Downloaded  736 / 778
# Downloaded  737 / 778
# Downloaded  738 / 778
# Downloaded  739 / 778
# Downloaded  740 / 778
# Downloaded  741 / 778
# Downloaded  742 / 778
# Downloaded  743 / 778
# Downloaded  744 / 778
# Downloaded  745 / 778
# Downloaded  746 / 778
# Downloaded  747 / 778
# Downloaded  748 / 778
# Downloaded  749 / 778
# Downloaded  750 / 778
# Downloaded  751 / 778
# Downloaded  752 / 778
# Downloaded  753 / 778
# Downloaded  754 / 778
# Downloaded  755 / 778
# Downloaded  756 / 778
# Downloaded  757 / 778
# Downloaded  758 / 778
# Downloaded  759 / 778
# Downloaded  760 / 778
# Downloaded  761 / 778
# Downloaded  762 / 778
# Downloaded  763 / 778
# Downloaded  764 / 778
# Downloaded  765 / 778
# Downloaded  766 / 778
# Downloaded  767 / 778
# Downloaded  768 / 778
# Downloaded  769 / 778
# Downloaded  770 / 778
# Downloaded  771 / 778
# Downloaded  772 / 778
# Downloaded  773 / 778
# Downloaded  774 / 778
# Downloaded  775 / 778
# Downloaded  776 / 778
# Downloaded  777 / 778
# Downloaded  778 / 778
# download files: t3 =  109.25

# %%
# Parent directory of all excel files
xlsx_files_root_dir = "C:/Users/benfl/OneDrive - Flexible Power Systems Ltd/Documents/Python Scripts/Waitrose Collation/raw_data_07022020"

# Name columns for dataframe
route_columns = ['Route_ID','Branch_ID','FL_Name','Start_Date_of_Route','Start_Time_of_Route','End_Time_of_Route',\
'Break_Duration_mins','Percentage_Shift_Time_used','Percentage_Van_Weight_used','Percentage_Ambient_Capacity_Used',\
'Percentage_Chilled_Capacity_Used','Percentage_Frozen_Capacity_Used','Percentage_Total_Crate_capacity_Used',\
'Planned_total_Route_time','Planned_Total_Wait_time_mins','Planned_total_Mileage','Planned_Total_Driving_time',\
'Number_Orders','Van_Type','Loaded_Ambient_Crates','Loaded_Chilled_Crates','Loaded_Frozen_Crates','Loaded_Kgs',\
'Loaded_Total_Crates','Total_Dwell_Time','Shift_Start_Time','Shift_End_Time','Total_Shift_Hours',\
'Total_Shift_Time_Spent_at_FL','MPO','HPO']

order_columns = ['Route_ID','Order_Sequence','Order_ID','Order_Type','Order_Delivery_Date','Time_Window_Start',\
         'Time_Window_End','Planned_Arrival_Time','Planned_Departure_Time','Break_Duration_Minutes',\
         'Wait_Time_since_Prev_Stop_Minutes','Post_Code','X_Coord','Y_Coord','MPO','Driving_Mins_Per_Order',\
         'Ambient','Chilled','Frozen','Total','Kg','Dwell_Time']

# %%
Route_ID_route = []
Branch_ID_route = []
FL_Name_route = []
Start_Date_of_Route_route = []
Start_Time_of_Route_route = []
End_Time_of_Route_route = []
Break_Duration_mins_route = []
Percentage_Shift_Time_used_route = []
Percentage_Van_Weight_used_route = []
Percentage_Ambient_Capacity_Used_route = []
Percentage_Chilled_Capacity_Used_route = []
Percentage_Frozen_Capacity_Used_route = []
Percentage_Total_Crate_capacity_Used_route = []
Planned_total_Route_time_route = []
Planned_Total_Wait_time_mins_route = []
Planned_total_Mileage_route = []
Planned_Total_Driving_time_route = []
Number_Orders_route= []
Van_Type_route = []
Loaded_Ambient_Crates_route = []
Loaded_Chilled_Crates_route = []
Loaded_Frozen_Crates_route = []
Loaded_Kgs_route = []
Loaded_Total_Crates_route = []
Total_Dwell_Time_route = []
Shift_Start_Time_route = []
Shift_End_Time_route = []
Total_Shift_Hours_route = []
Total_Shift_Time_Spent_at_FL_route = []
MPO_route = []
HPO_route = []
                
Route_ID_order = []
Order_Sequence_order = []           
Order_ID_order = []                 
Order_Type_order = []              
Order_Delivery_Date_order = []                    
Time_Window_Start_order = []                   
Time_Window_End_order = []                 
Planned_Arrival_Time_order = []                  
Planned_Departure_Time_order = []                   
Break_Duration_Minutes_order = []                  
Wait_Time_since_Prev_Stop_Minutes_order = []           
Post_Code_order = []             
X_Coord_order = []                
Y_Coord_order = []                  
MPO_order = []
Driving_Mins_Per_Order_order = []                 
Ambient_order = []                
Chilled_order = []             
Frozen_order = []                   
Total_order = []                 
Kg_order = []                 
Dwell_Time_order = []

# %%
# Initialise row to write data to
rt_idx = 0
od_idx = 0
# Fetches all files in directory and loops thorough each file
t10 = time.process_time()
for (dirpath, dirnames, filenames) in walk(xlsx_files_root_dir):
    for filename in filenames: 
        t4 = time.process_time()
        print(filename)
        start = time.time()
        # Reading excel data
        data = pd.read_excel(os.path.join(dirpath,filename),keep_default_na=False)
        total_rows = len(data)
        i=0
        j=3
        
        while i >= 0:
            j = 3
            i = find_index_total_route(data,total_rows,i,j) # As Waitrose use fixed template, always find "Total routes" first. From that index getting rest will be easy
            if i == -1:
                # End of file
                break
            total_route_cell_value = data.iloc[i,j] # Usually the string is "Total routes: ###"
            cell_split = total_route_cell_value.split(":") # Split the string with ":"
            total_routes_str = cell_split[1].strip() # second part of split string will be total number of routes
            total_routes = int(total_routes_str)
            
            rcnt = 0
            while rcnt < total_routes:  # Loop total_routes number of time to get route and corresponding orders for each route
                t2 = time.process_time()
                j = 3
                
                route_id_index = find_route_id_index(data,total_rows,i,j) # Fetch index of "Route ID"
                if route_id_index == -1:
                    # End of file
                    break
                
                route_id = data.iloc[route_id_index,j] # Get "Route ID"
                
                i = route_id_index

                index = find_index_branch_id(data,total_rows,i,j) # Get index of "Branch ID"
                i = index[0]
                j = index[1]

                first_branh_id_index = i + 1
                branch_id = data.iloc[first_branh_id_index,j] # Get "Branch ID"
                
                i = first_branh_id_index
                
                rest_route_data = read_rest_of_route_data(data,total_rows,i,j) # Get rest of route data
                
                j = 3
                
                # Waitrose use two standard template. In one the total number of route data column is 33 and the other is 32
                # Based on column count, need to set offset_index as data position differs between templates
                offset_index = 0
                if len(rest_route_data) == 33:
                    offset_index = 1
                else:
                    offset_index = 0
                
                # Get all route data
                t0 = time.process_time()
                Route_ID_route.append(route_id)
                Branch_ID_route.append(branch_id)
                FL_Name_route.append(rest_route_data[1])
                Start_Date_of_Route_route.append(get_date(rest_route_data[4]))
                Start_Time_of_Route_route.append(get_time(rest_route_data[5]))
                End_Time_of_Route_route.append(get_time(rest_route_data[7]))
                Break_Duration_mins_route.append(int(rest_route_data[8]))
                Percentage_Shift_Time_used_route.append(get_percentage(rest_route_data[9]))
                Percentage_Van_Weight_used_route.append(get_percentage(rest_route_data[10]))
                Percentage_Ambient_Capacity_Used_route.append(get_percentage(rest_route_data[11]))
                Percentage_Chilled_Capacity_Used_route.append(get_percentage(rest_route_data[12]))
                Percentage_Frozen_Capacity_Used_route.append(get_percentage(rest_route_data[13]))
                Percentage_Total_Crate_capacity_Used_route.append(get_percentage(rest_route_data[14]))
                Planned_total_Route_time_route.append(get_time(rest_route_data[15]))
                Planned_Total_Wait_time_mins_route.append(int(rest_route_data[16]))
                Planned_total_Mileage_route.append(float(rest_route_data[17]))
                Planned_Total_Driving_time_route.append(0)	
                Number_Orders_route.append(int(rest_route_data[18+offset_index]))	
                Van_Type_route.append(rest_route_data[19+offset_index])	
                Loaded_Ambient_Crates_route.append(int(rest_route_data[20+offset_index]))
                Loaded_Chilled_Crates_route.append(int(rest_route_data[21+offset_index]))
                Loaded_Frozen_Crates_route.append(int(rest_route_data[22+offset_index]))
                Loaded_Kgs_route.append(float(rest_route_data[23+offset_index]))
                Loaded_Total_Crates_route.append(int(rest_route_data[24+offset_index]))
                Total_Dwell_Time_route.append(float(rest_route_data[25+offset_index]))
                Shift_Start_Time_route.append(get_time(rest_route_data[26+offset_index]))
                Shift_End_Time_route.append(get_time(rest_route_data[27+offset_index]))
                Total_Shift_Hours_route.append(get_time(rest_route_data[28+offset_index]))
                Total_Shift_Time_Spent_at_FL_route.append(int(rest_route_data[29+offset_index]))
                MPO_route.append(float(rest_route_data[30+offset_index]))
                HPO_route.append(get_time(rest_route_data[31+offset_index]))
                t1 = time.process_time()
                total = t1-t0

                rt_idx += 1

                i = i + 3
                j = j + 4
                jindex = j
                order_data = []
                ocnt=0
                Number_Orders = int(rest_route_data[18+offset_index])
                #print('Numb orders = ', Number_Orders)
                while ocnt < Number_Orders: # For each route, loop "Number_orders" time and get order data
                    colcnt = 0
                    while colcnt < 24:
                        cell_value = data.iloc[i,j]
                        if str(cell_value) != 'NaT':
                            order_data.append(cell_value)
                        j+=1
                        colcnt+=1
                    ocnt+=1
                    
                    # Get order data
                    t0 = time.process_time()
                    Route_ID_order.append(route_id)
                    Order_Sequence_order.append(get_int(order_data[0]))                    
                    Order_ID_order.append(get_int(order_data[2]))                    
                    Order_Type_order.append(order_data[3])                    
                    Order_Delivery_Date_order.append(get_date(order_data[5]))                    
                    Time_Window_Start_order.append(get_time(order_data[6]))                    
                    Time_Window_End_order.append(get_time(order_data[7]))                    
                    Planned_Arrival_Time_order.append(get_time(order_data[8]))                    
                    Planned_Departure_Time_order.append(get_time(order_data[9]))                    
                    Break_Duration_Minutes_order.append(get_int(order_data[10]))                    
                    Wait_Time_since_Prev_Stop_Minutes_order.append(get_float(order_data[11]))                    
                    Post_Code_order.append(order_data[12])                    
                    X_Coord_order.append(get_float(order_data[13]))                    
                    Y_Coord_order.append(get_float(order_data[14]))                    
                    MPO_order.append(get_float(order_data[15]))
                    Driving_Mins_Per_Order_order.append(0)                    
                    Ambient_order.append(get_int(order_data[17]))                    
                    Chilled_order.append(get_int(order_data[18]))                    
                    Frozen_order.append(get_int(order_data[19]))                    
                    Total_order.append(get_int(order_data[20]))                    
                    Kg_order.append(get_float(order_data[21]))                    
                    Dwell_Time_order.append(get_float(order_data[22]))
                    t1 = time.process_time()
                    total = t1-t0

                    od_idx += 1

                    order_data = []
                    i+=1
                    j=jindex
                rcnt+=1
                t3 = time.process_time()
                passt = t3-t2
                #print('this route: passt = ', passt)
                
        t5 = time.process_time()
        filet = t5-t4
        print('this file: filet = ', filet)

t11 = time.process_time()
tott = t11-t10
print("Total run time = ", tott)
# Out:
# Daily_Report_Scheduled-2020_01_31_033101.xlsx
# this file: filet =  11.484375
# Daily_Report_Scheduled-2020_02_01_033103.xlsx
# this file: filet =  14.96875
# Daily_Report_Scheduled-2020_02_02_033123.xlsx
# this file: filet =  20.15625
# Daily_Report_Scheduled-2020_02_03_033116.xlsx
# this file: filet =  17.453125
# Daily_Report_Scheduled-2020_02_04_033101.xlsx
# this file: filet =  13.21875
# Daily_Report_Scheduled-2020_02_05_033107.xlsx
# this file: filet =  10.640625
# Daily_Report_Scheduled-2020_02_06_033059.xlsx
# this file: filet =  7.4375
# Daily_Report_Scheduled-2020_02_07_033052.xlsx
# this file: filet =  7.0625
# Daily_Report_Scheduled_2018_01_01_033044.xlsx
# this file: filet =  9.65625
# Daily_Report_Scheduled_2018_01_02_044846.xlsx
# this file: filet =  7.296875
# Daily_Report_Scheduled_2018_01_03_033117.xlsx
# this file: filet =  0.28125
# Daily_Report_Scheduled_2018_01_04_044809.xlsx
# this file: filet =  7.421875
# Daily_Report_Scheduled_2018_01_05_044912.xlsx
# this file: filet =  7.46875
# Daily_Report_Scheduled_2018_01_06_044912.xlsx
# this file: filet =  8.15625
# Daily_Report_Scheduled_2018_01_07_044923.xlsx
# this file: filet =  10.203125
# Daily_Report_Scheduled_2018_01_08_033048.xlsx
# this file: filet =  10.421875
# Daily_Report_Scheduled_2018_01_09_061129.xlsx
# this file: filet =  9.3125
# Daily_Report_Scheduled_2018_01_10_033118.xlsx
# this file: filet =  7.5625
# Daily_Report_Scheduled_2018_01_11_033042.xlsx
# this file: filet =  7.34375
# Daily_Report_Scheduled_2018_01_12_033046.xlsx
# this file: filet =  6.796875
# Daily_Report_Scheduled_2018_01_13_033054.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2018_01_14_033053.xlsx
# this file: filet =  14.09375
# Daily_Report_Scheduled_2018_01_15_033056.xlsx
# this file: filet =  18.25
# Daily_Report_Scheduled_2018_01_16_033046.xlsx
# this file: filet =  10.0
# Daily_Report_Scheduled_2018_01_17_033045.xlsx
# this file: filet =  9.25
# Daily_Report_Scheduled_2018_01_18_033049.xlsx
# this file: filet =  8.265625
# Daily_Report_Scheduled_2018_01_19_033046.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2018_01_20_033101.xlsx
# this file: filet =  11.546875
# Daily_Report_Scheduled_2018_01_21_033100.xlsx
# this file: filet =  16.125
# Daily_Report_Scheduled_2018_01_22_033051.xlsx
# this file: filet =  14.515625
# Daily_Report_Scheduled_2018_01_23_033049.xlsx
# this file: filet =  8.140625
# Daily_Report_Scheduled_2018_01_24_033051.xlsx
# this file: filet =  8.6875
# Daily_Report_Scheduled_2018_01_25_033044.xlsx
# this file: filet =  9.84375
# Daily_Report_Scheduled_2018_01_26_033052.xlsx
# this file: filet =  9.609375
# Daily_Report_Scheduled_2018_01_27_033048.xlsx
# this file: filet =  11.984375
# Daily_Report_Scheduled_2018_01_28_033058.xlsx
# this file: filet =  12.359375
# Daily_Report_Scheduled_2018_01_29_033053.xlsx
# this file: filet =  10.765625
# Daily_Report_Scheduled_2018_01_30_033054.xlsx
# this file: filet =  8.28125
# Daily_Report_Scheduled_2018_01_31_033056.xlsx
# this file: filet =  8.046875
# Daily_Report_Scheduled_2018_02_01_033048.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2018_02_02_033057.xlsx
# this file: filet =  8.96875
# Daily_Report_Scheduled_2018_02_03_033056.xlsx
# this file: filet =  11.03125
# Daily_Report_Scheduled_2018_02_04_033110.xlsx
# this file: filet =  15.34375
# Daily_Report_Scheduled_2018_02_05_033100.xlsx
# this file: filet =  10.890625
# Daily_Report_Scheduled_2018_02_06_033058.xlsx
# this file: filet =  8.0
# Daily_Report_Scheduled_2018_02_07_033117.xlsx
# this file: filet =  8.59375
# Daily_Report_Scheduled_2018_02_08_033050.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2018_02_09_033052.xlsx
# this file: filet =  7.125
# Daily_Report_Scheduled_2018_02_10_033053.xlsx
# this file: filet =  10.21875
# Daily_Report_Scheduled_2018_02_11_033101.xlsx
# this file: filet =  18.0625
# Daily_Report_Scheduled_2018_02_12_033056.xlsx
# this file: filet =  16.78125
# Daily_Report_Scheduled_2018_02_13_033047.xlsx
# this file: filet =  7.921875
# Daily_Report_Scheduled_2018_02_14_033052.xlsx
# this file: filet =  8.0625
# Daily_Report_Scheduled_2018_02_15_033046.xlsx
# this file: filet =  7.828125
# Daily_Report_Scheduled_2018_02_16_033052.xlsx
# this file: filet =  8.28125
# Daily_Report_Scheduled_2018_02_17_033051.xlsx
# this file: filet =  8.703125
# Daily_Report_Scheduled_2018_02_18_033100.xlsx
# this file: filet =  14.671875
# Daily_Report_Scheduled_2018_02_19_033051.xlsx
# this file: filet =  13.65625
# Daily_Report_Scheduled_2018_02_20_033045.xlsx
# this file: filet =  11.390625
# Daily_Report_Scheduled_2018_02_21_033047.xlsx
# this file: filet =  9.609375
# Daily_Report_Scheduled_2018_02_22_044918.xlsx
# this file: filet =  9.4375
# Daily_Report_Scheduled_2018_02_23_044916.xlsx
# this file: filet =  11.265625
# Daily_Report_Scheduled_2018_02_24_044923.xlsx
# this file: filet =  8.625
# Daily_Report_Scheduled_2018_02_25_044932.xlsx
# this file: filet =  11.90625
# Daily_Report_Scheduled_2018_02_26_044927.xlsx
# this file: filet =  9.25
# Daily_Report_Scheduled_2018_02_27_044852.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2018_02_28_033055.xlsx
# this file: filet =  8.09375
# Daily_Report_Scheduled_2018_03_01_044919.xlsx
# this file: filet =  8.0625
# Daily_Report_Scheduled_2018_03_02_044917.xlsx
# this file: filet =  9.703125
# Daily_Report_Scheduled_2018_03_03_044750.xlsx
# this file: filet =  11.171875
# Daily_Report_Scheduled_2018_03_04_044143.xlsx
# this file: filet =  10.125
# Daily_Report_Scheduled_2018_03_05_044222.xlsx
# this file: filet =  13.203125
# Daily_Report_Scheduled_2018_03_06_033042.xlsx
# this file: filet =  9.9375
# Daily_Report_Scheduled_2018_03_07_033049.xlsx
# this file: filet =  13.671875
# Daily_Report_Scheduled_2018_03_08_033059.xlsx
# this file: filet =  12.859375
# Daily_Report_Scheduled_2018_03_09_033054.xlsx
# this file: filet =  11.28125
# Daily_Report_Scheduled_2018_03_10_033101.xlsx
# this file: filet =  10.53125
# Daily_Report_Scheduled_2018_03_11_033102.xlsx
# this file: filet =  19.109375
# Daily_Report_Scheduled_2018_03_12_033101.xlsx
# this file: filet =  15.4375
# Daily_Report_Scheduled_2018_03_13_033049.xlsx
# this file: filet =  9.375
# Daily_Report_Scheduled_2018_03_14_033055.xlsx
# this file: filet =  10.6875
# Daily_Report_Scheduled_2018_03_15_033052.xlsx
# this file: filet =  9.765625
# Daily_Report_Scheduled_2018_03_16_033045.xlsx
# this file: filet =  8.90625
# Daily_Report_Scheduled_2018_03_17_033054.xlsx
# this file: filet =  11.34375
# Daily_Report_Scheduled_2018_03_18_033104.xlsx
# this file: filet =  17.984375
# Daily_Report_Scheduled_2018_03_19_033058.xlsx
# this file: filet =  14.625
# Daily_Report_Scheduled_2018_03_20_033048.xlsx
# this file: filet =  9.421875
# Daily_Report_Scheduled_2018_03_21_033059.xlsx
# this file: filet =  11.234375
# Daily_Report_Scheduled_2018_03_22_033052.xlsx
# this file: filet =  11.84375
# Daily_Report_Scheduled_2018_03_23_033050.xlsx
# this file: filet =  10.484375
# Daily_Report_Scheduled_2018_03_24_033055.xlsx
# this file: filet =  11.515625
# Daily_Report_Scheduled_2018_03_25_033103.xlsx
# this file: filet =  15.53125
# Daily_Report_Scheduled_2018_03_26_033102.xlsx
# this file: filet =  15.6875
# Daily_Report_Scheduled_2018_03_27_033055.xlsx
# this file: filet =  9.234375
# Daily_Report_Scheduled_2018_03_28_033057.xlsx
# this file: filet =  8.921875
# Daily_Report_Scheduled_2018_03_29_033053.xlsx
# this file: filet =  7.171875
# Daily_Report_Scheduled_2018_03_30_033103.xlsx
# this file: filet =  7.453125
# Daily_Report_Scheduled_2018_03_31_033105.xlsx
# this file: filet =  11.9375
# Daily_Report_Scheduled_2018_04_01_033112.xlsx
# this file: filet =  13.25
# Daily_Report_Scheduled_2018_04_02_033058.xlsx
# this file: filet =  10.40625
# Daily_Report_Scheduled_2018_04_03_033031.xlsx
# this file: filet =  0.8125
# Daily_Report_Scheduled_2018_04_04_033046.xlsx
# this file: filet =  6.046875
# Daily_Report_Scheduled_2018_04_05_033046.xlsx
# this file: filet =  6.984375
# Daily_Report_Scheduled_2018_04_06_033051.xlsx
# this file: filet =  6.484375
# Daily_Report_Scheduled_2018_04_07_033050.xlsx
# this file: filet =  8.34375
# Daily_Report_Scheduled_2018_04_08_033104.xlsx
# this file: filet =  13.65625
# Daily_Report_Scheduled_2018_04_09_033054.xlsx
# this file: filet =  9.953125
# Daily_Report_Scheduled_2018_04_10_033051.xlsx
# this file: filet =  7.40625
# Daily_Report_Scheduled_2018_04_11_033046.xlsx
# this file: filet =  8.453125
# Daily_Report_Scheduled_2018_04_12_033043.xlsx
# this file: filet =  7.25
# Daily_Report_Scheduled_2018_04_13_033049.xlsx
# this file: filet =  7.03125
# Daily_Report_Scheduled_2018_04_14_033044.xlsx
# this file: filet =  8.09375
# Daily_Report_Scheduled_2018_04_15_033058.xlsx
# this file: filet =  11.921875
# Daily_Report_Scheduled_2018_04_16_033046.xlsx
# this file: filet =  10.484375
# Daily_Report_Scheduled_2018_04_17_033043.xlsx
# this file: filet =  7.34375
# Daily_Report_Scheduled_2018_04_18_033045.xlsx
# this file: filet =  7.671875
# Daily_Report_Scheduled_2018_04_19_033049.xlsx
# this file: filet =  7.234375
# Daily_Report_Scheduled_2018_04_20_033040.xlsx
# this file: filet =  6.484375
# Daily_Report_Scheduled_2018_04_21_033045.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2018_04_22_033054.xlsx
# this file: filet =  15.25
# Daily_Report_Scheduled_2018_04_23_033057.xlsx
# this file: filet =  11.265625
# Daily_Report_Scheduled_2018_04_24_033043.xlsx
# this file: filet =  7.359375
# Daily_Report_Scheduled_2018_04_25_033054.xlsx
# this file: filet =  6.984375
# Daily_Report_Scheduled_2018_04_26_033051.xlsx
# this file: filet =  7.21875
# Daily_Report_Scheduled_2018_04_27_033058.xlsx
# this file: filet =  6.71875
# Daily_Report_Scheduled_2018_04_28_033101.xlsx
# this file: filet =  8.828125
# Daily_Report_Scheduled_2018_04_29_033113.xlsx
# this file: filet =  11.046875
# Daily_Report_Scheduled_2018_04_30_033110.xlsx
# this file: filet =  9.03125
# Daily_Report_Scheduled_2018_05_01_033058.xlsx
# this file: filet =  7.375
# Daily_Report_Scheduled_2018_05_02_033104.xlsx
# this file: filet =  7.953125
# Daily_Report_Scheduled_2018_05_03_033101.xlsx
# this file: filet =  8.53125
# Daily_Report_Scheduled_2018_05_04_033055.xlsx
# this file: filet =  7.328125
# Daily_Report_Scheduled_2018_05_05_033103.xlsx
# this file: filet =  11.078125
# Daily_Report_Scheduled_2018_05_06_033108.xlsx
# this file: filet =  12.96875
# Daily_Report_Scheduled_2018_05_07_033053.xlsx
# this file: filet =  10.453125
# Daily_Report_Scheduled_2018_05_08_033045.xlsx
# this file: filet =  7.640625
# Daily_Report_Scheduled_2018_05_09_033043.xlsx
# this file: filet =  6.71875
# Daily_Report_Scheduled_2018_05_10_033042.xlsx
# this file: filet =  8.296875
# Daily_Report_Scheduled_2018_05_11_033037.xlsx
# this file: filet =  3.78125
# Daily_Report_Scheduled_2018_05_12_033031.xlsx
# this file: filet =  4.328125
# Daily_Report_Scheduled_2018_05_13_033058.xlsx
# this file: filet =  12.515625
# Daily_Report_Scheduled_2018_05_14_033051.xlsx
# this file: filet =  9.96875
# Daily_Report_Scheduled_2018_05_15_033043.xlsx
# this file: filet =  8.625
# Daily_Report_Scheduled_2018_05_16_033046.xlsx
# this file: filet =  7.734375
# Daily_Report_Scheduled_2018_05_17_033051.xlsx
# this file: filet =  7.609375
# Daily_Report_Scheduled_2018_05_18_033057.xlsx
# this file: filet =  6.625
# Daily_Report_Scheduled_2018_05_19_033056.xlsx
# this file: filet =  9.625
# Daily_Report_Scheduled_2018_05_20_033102.xlsx
# this file: filet =  12.234375
# Daily_Report_Scheduled_2018_05_21_033050.xlsx
# this file: filet =  9.5
# Daily_Report_Scheduled_2018_05_22_033039.xlsx
# this file: filet =  7.984375
# Daily_Report_Scheduled_2018_05_23_033047.xlsx
# this file: filet =  7.5625
# Daily_Report_Scheduled_2018_05_24_033040.xlsx
# this file: filet =  7.171875
# Daily_Report_Scheduled_2018_05_25_033048.xlsx
# this file: filet =  6.671875
# Daily_Report_Scheduled_2018_05_26_033048.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2018_05_27_033059.xlsx
# this file: filet =  13.046875
# Daily_Report_Scheduled_2018_05_28_033048.xlsx
# this file: filet =  13.84375
# Daily_Report_Scheduled_2018_05_29_033051.xlsx
# this file: filet =  7.296875
# Daily_Report_Scheduled_2018_05_30_033041.xlsx
# this file: filet =  8.703125
# Daily_Report_Scheduled_2018_05_31_033051.xlsx
# this file: filet =  10.875
# Daily_Report_Scheduled_2018_06_01_033053.xlsx
# this file: filet =  10.703125
# Daily_Report_Scheduled_2018_06_02_033056.xlsx
# this file: filet =  9.359375
# Daily_Report_Scheduled_2018_06_03_033100.xlsx
# this file: filet =  11.203125
# Daily_Report_Scheduled_2018_06_04_033059.xlsx
# this file: filet =  10.625
# Daily_Report_Scheduled_2018_06_05_033043.xlsx
# this file: filet =  7.046875
# Daily_Report_Scheduled_2018_06_06_033045.xlsx
# this file: filet =  7.1875
# Daily_Report_Scheduled_2018_06_07_033045.xlsx
# this file: filet =  7.4375
# Daily_Report_Scheduled_2018_06_08_033047.xlsx
# this file: filet =  6.5625
# Daily_Report_Scheduled_2018_06_09_033054.xlsx
# this file: filet =  8.0625
# Daily_Report_Scheduled_2018_06_10_033058.xlsx
# this file: filet =  11.359375
# Daily_Report_Scheduled_2018_06_11_033058.xlsx
# this file: filet =  10.359375
# Daily_Report_Scheduled_2018_06_12_033046.xlsx
# this file: filet =  7.03125
# Daily_Report_Scheduled_2018_06_13_033050.xlsx
# this file: filet =  7.25
# Daily_Report_Scheduled_2018_06_14_033044.xlsx
# this file: filet =  7.546875
# Daily_Report_Scheduled_2018_06_15_033045.xlsx
# this file: filet =  7.53125
# Daily_Report_Scheduled_2018_06_16_033047.xlsx
# this file: filet =  8.453125
# Daily_Report_Scheduled_2018_06_17_033104.xlsx
# this file: filet =  13.09375
# Daily_Report_Scheduled_2018_06_18_033055.xlsx
# this file: filet =  10.5
# Daily_Report_Scheduled_2018_06_20_033043.xlsx
# this file: filet =  9.296875
# Daily_Report_Scheduled_2018_06_21_033042.xlsx
# this file: filet =  6.90625
# Daily_Report_Scheduled_2018_06_22_033044.xlsx
# this file: filet =  6.40625
# Daily_Report_Scheduled_2018_06_23_033054.xlsx
# this file: filet =  7.765625
# Daily_Report_Scheduled_2018_06_24_033057.xlsx
# this file: filet =  11.84375
# Daily_Report_Scheduled_2018_06_25_033052.xlsx
# this file: filet =  10.046875
# Daily_Report_Scheduled_2018_06_26_033047.xlsx
# this file: filet =  7.21875
# Daily_Report_Scheduled_2018_06_27_033049.xlsx
# this file: filet =  7.703125
# Daily_Report_Scheduled_2018_06_28_033048.xlsx
# this file: filet =  8.6875
# Daily_Report_Scheduled_2018_06_29_033046.xlsx
# this file: filet =  8.640625
# Daily_Report_Scheduled_2018_06_30_033057.xlsx
# this file: filet =  8.84375
# Daily_Report_Scheduled_2018_07_01_033056.xlsx
# this file: filet =  13.5
# Daily_Report_Scheduled_2018_07_02_033052.xlsx
# this file: filet =  10.296875
# Daily_Report_Scheduled_2018_07_03_033046.xlsx
# this file: filet =  10.171875
# Daily_Report_Scheduled_2018_07_04_033053.xlsx
# this file: filet =  17.96875
# Daily_Report_Scheduled_2018_07_05_033053.xlsx
# this file: filet =  10.78125
# Daily_Report_Scheduled_2018_07_06_033047.xlsx
# this file: filet =  8.90625
# Daily_Report_Scheduled_2018_07_07_033052.xlsx
# this file: filet =  8.578125
# Daily_Report_Scheduled_2018_07_08_033102.xlsx
# this file: filet =  12.125
# Daily_Report_Scheduled_2018_07_09_033050.xlsx
# this file: filet =  10.4375
# Daily_Report_Scheduled_2018_07_10_033047.xlsx
# this file: filet =  7.546875
# Daily_Report_Scheduled_2018_07_11_033048.xlsx
# this file: filet =  7.4375
# Daily_Report_Scheduled_2018_07_12_033040.xlsx
# this file: filet =  7.1875
# Daily_Report_Scheduled_2018_07_13_033040.xlsx
# this file: filet =  6.265625
# Daily_Report_Scheduled_2018_07_14_033044.xlsx
# this file: filet =  8.53125
# Daily_Report_Scheduled_2018_07_15_033057.xlsx
# this file: filet =  14.453125
# Daily_Report_Scheduled_2018_07_16_033054.xlsx
# this file: filet =  11.921875
# Daily_Report_Scheduled_2018_07_17_033040.xlsx
# this file: filet =  12.640625
# Daily_Report_Scheduled_2018_07_18_033045.xlsx
# this file: filet =  15.40625
# Daily_Report_Scheduled_2018_07_19_033048.xlsx
# this file: filet =  10.15625
# Daily_Report_Scheduled_2018_07_20_033053.xlsx
# this file: filet =  9.0625
# Daily_Report_Scheduled_2018_07_21_033052.xlsx
# this file: filet =  12.46875
# Daily_Report_Scheduled_2018_07_22_033102.xlsx
# this file: filet =  15.859375
# Daily_Report_Scheduled_2018_07_23_033057.xlsx
# this file: filet =  13.765625
# Daily_Report_Scheduled_2018_07_24_033051.xlsx
# this file: filet =  9.140625
# Daily_Report_Scheduled_2018_07_25_033043.xlsx
# this file: filet =  10.0
# Daily_Report_Scheduled_2018_07_26_033047.xlsx
# this file: filet =  9.203125
# Daily_Report_Scheduled_2018_07_27_033048.xlsx
# this file: filet =  10.25
# Daily_Report_Scheduled_2018_07_28_033058.xlsx
# this file: filet =  12.0625
# Daily_Report_Scheduled_2018_07_29_033110.xlsx
# this file: filet =  18.8125
# Daily_Report_Scheduled_2018_07_30_033056.xlsx
# this file: filet =  14.015625
# Daily_Report_Scheduled_2018_07_31_033046.xlsx
# this file: filet =  7.046875
# Daily_Report_Scheduled_2018_08_01_033050.xlsx
# this file: filet =  8.515625
# Daily_Report_Scheduled_2018_08_02_033011.xlsx
# this file: filet =  0.0
# Daily_Report_Scheduled_2018_08_03_033017.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2018_08_04_033051.xlsx
# this file: filet =  10.78125
# Daily_Report_Scheduled_2018_08_05_033105.xlsx
# this file: filet =  11.90625
# Daily_Report_Scheduled_2018_08_06_033102.xlsx
# this file: filet =  9.859375
# Daily_Report_Scheduled_2018_08_07_033046.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2018_08_08_033052.xlsx
# this file: filet =  8.671875
# Daily_Report_Scheduled_2018_08_09_033049.xlsx
# this file: filet =  7.9375
# Daily_Report_Scheduled_2018_08_10_044841.xlsx
# this file: filet =  6.75
# Daily_Report_Scheduled_2018_08_11_044952.xlsx
# this file: filet =  8.265625
# Daily_Report_Scheduled_2018_08_12_044959.xlsx
# this file: filet =  14.53125
# Daily_Report_Scheduled_2018_08_13_044951.xlsx
# this file: filet =  13.328125
# Daily_Report_Scheduled_2018_08_14_044946.xlsx
# this file: filet =  9.515625
# Daily_Report_Scheduled_2018_08_15_044950.xlsx
# this file: filet =  8.453125
# Daily_Report_Scheduled_2018_08_16_044942.xlsx
# this file: filet =  7.234375
# Daily_Report_Scheduled_2018_08_17_044946.xlsx
# this file: filet =  7.421875
# Daily_Report_Scheduled_2018_08_18_044953.xlsx
# this file: filet =  8.390625
# Daily_Report_Scheduled_2018_08_19_045002.xlsx
# this file: filet =  19.953125
# Daily_Report_Scheduled_2018_08_20_033055.xlsx
# this file: filet =  20.171875
# Daily_Report_Scheduled_2018_08_21_033045.xlsx
# this file: filet =  16.546875
# Daily_Report_Scheduled_2018_08_22_044945.xlsx
# this file: filet =  10.640625
# Daily_Report_Scheduled_2018_08_23_044949.xlsx
# this file: filet =  8.25
# Daily_Report_Scheduled_2018_08_24_044950.xlsx
# this file: filet =  8.765625
# Daily_Report_Scheduled_2018_08_25_044945.xlsx
# this file: filet =  12.0
# Daily_Report_Scheduled_2018_08_26_045006.xlsx
# this file: filet =  14.234375
# Daily_Report_Scheduled_2018_08_27_044953.xlsx
# this file: filet =  11.75
# Daily_Report_Scheduled_2018_08_28_044945.xlsx
# this file: filet =  7.984375
# Daily_Report_Scheduled_2018_08_29_044944.xlsx
# this file: filet =  8.4375
# Daily_Report_Scheduled_2018_08_30_044949.xlsx
# this file: filet =  9.78125
# Daily_Report_Scheduled_2018_08_31_044953.xlsx
# this file: filet =  10.25
# Daily_Report_Scheduled_2018_09_01_044950.xlsx
# this file: filet =  11.21875
# Daily_Report_Scheduled_2018_09_02_045007.xlsx
# this file: filet =  15.1875
# Daily_Report_Scheduled_2018_09_03_044952.xlsx
# this file: filet =  12.375
# Daily_Report_Scheduled_2018_09_04_044954.xlsx
# this file: filet =  11.734375
# Daily_Report_Scheduled_2018_09_05_033053.xlsx
# this file: filet =  10.03125
# Daily_Report_Scheduled_2018_09_06_044949.xlsx
# this file: filet =  9.40625
# Daily_Report_Scheduled_2018_09_07_044939.xlsx
# this file: filet =  8.046875
# Daily_Report_Scheduled_2018_09_08_044954.xlsx
# this file: filet =  9.859375
# Daily_Report_Scheduled_2018_09_09_045000.xlsx
# this file: filet =  14.453125
# Daily_Report_Scheduled_2018_09_10_044957.xlsx
# this file: filet =  12.09375
# Daily_Report_Scheduled_2018_09_11_044952.xlsx
# this file: filet =  12.171875
# Daily_Report_Scheduled_2018_09_12_044948.xlsx
# this file: filet =  8.78125
# Daily_Report_Scheduled_2018_09_13_033051.xlsx
# this file: filet =  7.28125
# Daily_Report_Scheduled_2018_09_14_033046.xlsx
# this file: filet =  7.484375
# Daily_Report_Scheduled_2018_09_15_033047.xlsx
# this file: filet =  9.15625
# Daily_Report_Scheduled_2018_09_16_033102.xlsx
# this file: filet =  16.15625
# Daily_Report_Scheduled_2018_09_17_033056.xlsx
# this file: filet =  11.390625
# Daily_Report_Scheduled_2018_09_18_033043.xlsx
# this file: filet =  7.796875
# Daily_Report_Scheduled_2018_09_19_033046.xlsx
# this file: filet =  8.28125
# Daily_Report_Scheduled_2018_09_20_033049.xlsx
# this file: filet =  7.359375
# Daily_Report_Scheduled_2018_09_21_033049.xlsx
# this file: filet =  6.78125
# Daily_Report_Scheduled_2018_09_22_033058.xlsx
# this file: filet =  8.234375
# Daily_Report_Scheduled_2018_09_23_033107.xlsx
# this file: filet =  12.421875
# Daily_Report_Scheduled_2018_09_24_033102.xlsx
# this file: filet =  10.125
# Daily_Report_Scheduled_2018_09_25_033053.xlsx
# this file: filet =  7.359375
# Daily_Report_Scheduled_2018_09_26_033053.xlsx
# this file: filet =  8.03125
# Daily_Report_Scheduled_2018_09_27_033053.xlsx
# this file: filet =  9.484375
# Daily_Report_Scheduled_2018_09_28_033057.xlsx
# this file: filet =  6.890625
# Daily_Report_Scheduled_2018_09_29_033104.xlsx
# this file: filet =  8.640625
# Daily_Report_Scheduled_2018_09_30_033115.xlsx
# this file: filet =  18.734375
# Daily_Report_Scheduled_2018_10_01_033102.xlsx
# this file: filet =  11.828125
# Daily_Report_Scheduled_2018_10_02_033059.xlsx
# this file: filet =  8.28125
# Daily_Report_Scheduled_2018_10_03_033101.xlsx
# this file: filet =  11.046875
# Daily_Report_Scheduled_2018_10_04_033104.xlsx
# this file: filet =  9.765625
# Daily_Report_Scheduled_2018_10_05_033102.xlsx
# this file: filet =  10.015625
# Daily_Report_Scheduled_2018_10_06_033102.xlsx
# this file: filet =  9.625
# Daily_Report_Scheduled_2018_10_07_033110.xlsx
# this file: filet =  12.390625
# Daily_Report_Scheduled_2018_10_08_033105.xlsx
# this file: filet =  11.09375
# Daily_Report_Scheduled_2018_10_09_033055.xlsx
# this file: filet =  13.515625
# Daily_Report_Scheduled_2018_10_10_033059.xlsx
# this file: filet =  8.40625
# Daily_Report_Scheduled_2018_10_11_033050.xlsx
# this file: filet =  7.453125
# Daily_Report_Scheduled_2018_10_12_033051.xlsx
# this file: filet =  6.671875
# Daily_Report_Scheduled_2018_10_13_033055.xlsx
# this file: filet =  8.109375
# Daily_Report_Scheduled_2018_10_14_033109.xlsx
# this file: filet =  12.125
# Daily_Report_Scheduled_2018_10_15_033101.xlsx
# this file: filet =  9.875
# Daily_Report_Scheduled_2018_10_16_033102.xlsx
# this file: filet =  7.53125
# Daily_Report_Scheduled_2018_10_17_033055.xlsx
# this file: filet =  8.84375
# Daily_Report_Scheduled_2018_10_18_033058.xlsx
# this file: filet =  7.75
# Daily_Report_Scheduled_2018_10_19_033054.xlsx
# this file: filet =  6.796875
# Daily_Report_Scheduled_2018_10_20_033102.xlsx
# this file: filet =  8.265625
# Daily_Report_Scheduled_2018_10_21_033108.xlsx
# this file: filet =  11.71875
# Daily_Report_Scheduled_2018_10_22_033105.xlsx
# this file: filet =  11.9375
# Daily_Report_Scheduled_2018_10_23_033055.xlsx
# this file: filet =  7.875
# Daily_Report_Scheduled_2018_10_24_033100.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2018_10_25_033055.xlsx
# this file: filet =  7.546875
# Daily_Report_Scheduled_2018_10_26_033104.xlsx
# this file: filet =  7.515625
# Daily_Report_Scheduled_2018_10_27_033108.xlsx
# this file: filet =  8.578125
# Daily_Report_Scheduled_2018_10_28_033111.xlsx
# this file: filet =  11.65625
# Daily_Report_Scheduled_2018_10_29_033104.xlsx
# this file: filet =  9.84375
# Daily_Report_Scheduled_2018_10_30_233030.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2018_10_31_233049.xlsx
# this file: filet =  7.1875
# Daily_Report_Scheduled_2018_11_01_033101.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2018_11_01_233048.xlsx
# this file: filet =  9.34375
# Daily_Report_Scheduled_2018_11_02_033211.xlsx
# this file: filet =  7.0
# Daily_Report_Scheduled_2018_11_02_233059.xlsx
# this file: filet =  11.140625
# Daily_Report_Scheduled_2018_11_03_033124.xlsx
# this file: filet =  7.78125
# Daily_Report_Scheduled_2018_11_03_233105.xlsx
# this file: filet =  11.359375
# Daily_Report_Scheduled_2018_11_04_033308.xlsx
# this file: filet =  11.109375
# Daily_Report_Scheduled_2018_11_04_233059.xlsx
# this file: filet =  7.53125
# Daily_Report_Scheduled_2018_11_05_033134.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2018_11_05_233055.xlsx
# this file: filet =  7.78125
# Daily_Report_Scheduled_2018_11_06_033100.xlsx
# this file: filet =  8.0
# Daily_Report_Scheduled_2018_11_07_033108.xlsx
# this file: filet =  9.1875
# Daily_Report_Scheduled_2018_11_08_033105.xlsx
# this file: filet =  8.6875
# Daily_Report_Scheduled_2018_11_09_033056.xlsx
# this file: filet =  7.953125
# Daily_Report_Scheduled_2018_11_10_033105.xlsx
# this file: filet =  12.71875
# Daily_Report_Scheduled_2018_11_11_033115.xlsx
# this file: filet =  14.3125
# Daily_Report_Scheduled_2018_11_12_043214.xlsx
# this file: filet =  10.21875
# Daily_Report_Scheduled_2018_11_13_033102.xlsx
# this file: filet =  10.359375
# Daily_Report_Scheduled_2018_11_14_033056.xlsx
# this file: filet =  8.109375
# Daily_Report_Scheduled_2018_11_15_033110.xlsx
# this file: filet =  7.953125
# Daily_Report_Scheduled_2018_11_16_033102.xlsx
# this file: filet =  7.3125
# Daily_Report_Scheduled_2018_11_17_033103.xlsx
# this file: filet =  8.328125
# Daily_Report_Scheduled_2018_11_18_033125.xlsx
# this file: filet =  12.46875
# Daily_Report_Scheduled_2018_11_19_033106.xlsx
# this file: filet =  10.546875
# Daily_Report_Scheduled_2018_11_20_033109.xlsx
# this file: filet =  8.53125
# Daily_Report_Scheduled_2018_11_21_033106.xlsx
# this file: filet =  8.953125
# Daily_Report_Scheduled_2018_11_22_033108.xlsx
# this file: filet =  9.015625
# Daily_Report_Scheduled_2018_11_23_033110.xlsx
# this file: filet =  7.9375
# Daily_Report_Scheduled_2018_11_24_033116.xlsx
# this file: filet =  9.125
# Daily_Report_Scheduled_2018_11_25_033125.xlsx
# this file: filet =  12.53125
# Daily_Report_Scheduled_2018_11_26_033123.xlsx
# this file: filet =  13.125
# Daily_Report_Scheduled_2018_11_27_033105.xlsx
# this file: filet =  8.0625
# Daily_Report_Scheduled_2018_11_28_033109.xlsx
# this file: filet =  8.734375
# Daily_Report_Scheduled_2018_11_29_033105.xlsx
# this file: filet =  8.390625
# Daily_Report_Scheduled_2018_11_30_033106.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2018_12_01_033120.xlsx
# this file: filet =  9.015625
# Daily_Report_Scheduled_2018_12_02_033128.xlsx
# this file: filet =  12.546875
# Daily_Report_Scheduled_2018_12_03_033111.xlsx
# this file: filet =  10.625
# Daily_Report_Scheduled_2018_12_04_033108.xlsx
# this file: filet =  9.421875
# Daily_Report_Scheduled_2018_12_05_033106.xlsx
# this file: filet =  9.15625
# Daily_Report_Scheduled_2018_12_06_033105.xlsx
# this file: filet =  8.140625
# Daily_Report_Scheduled_2018_12_07_033110.xlsx
# this file: filet =  7.828125
# Daily_Report_Scheduled_2018_12_08_033109.xlsx
# this file: filet =  10.5625
# Daily_Report_Scheduled_2018_12_09_033120.xlsx
# this file: filet =  12.671875
# Daily_Report_Scheduled_2018_12_10_033103.xlsx
# this file: filet =  13.203125
# Daily_Report_Scheduled_2018_12_11_033056.xlsx
# this file: filet =  8.140625
# Daily_Report_Scheduled_2018_12_12_033112.xlsx
# this file: filet =  8.71875
# Daily_Report_Scheduled_2018_12_13_033101.xlsx
# this file: filet =  8.796875
# Daily_Report_Scheduled_2018_12_14_033058.xlsx
# this file: filet =  8.203125
# Daily_Report_Scheduled_2018_12_15_033101.xlsx
# this file: filet =  9.890625
# Daily_Report_Scheduled_2018_12_16_033109.xlsx
# this file: filet =  14.296875
# Daily_Report_Scheduled_2018_12_17_033101.xlsx
# this file: filet =  11.984375
# Daily_Report_Scheduled_2018_12_18_033109.xlsx
# this file: filet =  9.296875
# Daily_Report_Scheduled_2018_12_19_033100.xlsx
# this file: filet =  11.6875
# Daily_Report_Scheduled_2018_12_20_033103.xlsx
# this file: filet =  13.25
# Daily_Report_Scheduled_2018_12_21_033120.xlsx
# this file: filet =  18.46875
# Daily_Report_Scheduled_2018_12_22_033127.xlsx
# this file: filet =  14.53125
# Daily_Report_Scheduled_2018_12_23_033119.xlsx
# this file: filet =  21.703125
# Daily_Report_Scheduled_2018_12_24_033114.xlsx
# this file: filet =  22.96875
# Daily_Report_Scheduled_2018_12_25_033113.xlsx
# this file: filet =  27.359375
# Daily_Report_Scheduled_2018_12_26_033033.xlsx
# this file: filet =  6.5625
# Daily_Report_Scheduled_2018_12_27_033007.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2018_12_28_033007.xlsx
# this file: filet =  0.0
# Daily_Report_Scheduled_2018_12_29_033036.xlsx
# this file: filet =  7.703125
# Daily_Report_Scheduled_2018_12_30_033056.xlsx
# this file: filet =  13.390625
# Daily_Report_Scheduled_2018_12_31_033055.xlsx
# this file: filet =  9.859375
# Daily_Report_Scheduled_2019_01_01_033042.xlsx
# this file: filet =  8.03125
# Daily_Report_Scheduled_2019_01_02_033047.xlsx
# this file: filet =  8.734375
# Daily_Report_Scheduled_2019_01_03_033025.xlsx
# this file: filet =  0.359375
# Daily_Report_Scheduled_2019_01_04_033050.xlsx
# this file: filet =  7.9375
# Daily_Report_Scheduled_2019_01_05_033102.xlsx
# this file: filet =  10.546875
# Daily_Report_Scheduled_2019_01_06_033113.xlsx
# this file: filet =  18.140625
# Daily_Report_Scheduled_2019_01_07_033059.xlsx
# this file: filet =  13.78125
# Daily_Report_Scheduled_2019_01_08_033059.xlsx
# this file: filet =  10.796875
# Daily_Report_Scheduled_2019_01_09_033053.xlsx
# this file: filet =  13.796875
# Daily_Report_Scheduled_2019_01_10_033049.xlsx
# this file: filet =  8.09375
# Daily_Report_Scheduled_2019_01_11_033057.xlsx
# this file: filet =  7.75
# Daily_Report_Scheduled_2019_01_12_033058.xlsx
# this file: filet =  9.078125
# Daily_Report_Scheduled_2019_01_13_033105.xlsx
# this file: filet =  12.5
# Daily_Report_Scheduled_2019_01_14_033101.xlsx
# this file: filet =  10.71875
# Daily_Report_Scheduled_2019_01_15_033050.xlsx
# this file: filet =  8.546875
# Daily_Report_Scheduled_2019_01_16_033056.xlsx
# this file: filet =  8.96875
# Daily_Report_Scheduled_2019_01_17_033048.xlsx
# this file: filet =  8.953125
# Daily_Report_Scheduled_2019_01_18_033054.xlsx
# this file: filet =  7.453125
# Daily_Report_Scheduled_2019_01_19_033054.xlsx
# this file: filet =  8.765625
# Daily_Report_Scheduled_2019_01_20_033102.xlsx
# this file: filet =  12.609375
# Daily_Report_Scheduled_2019_01_21_033059.xlsx
# this file: filet =  10.234375
# Daily_Report_Scheduled_2019_01_22_033110.xlsx
# this file: filet =  7.921875
# Daily_Report_Scheduled_2019_01_23_033045.xlsx
# this file: filet =  7.921875
# Daily_Report_Scheduled_2019_01_24_033046.xlsx
# this file: filet =  7.65625
# Daily_Report_Scheduled_2019_01_25_033049.xlsx
# this file: filet =  6.46875
# Daily_Report_Scheduled_2019_01_26_033054.xlsx
# this file: filet =  11.578125
# Daily_Report_Scheduled_2019_01_27_033101.xlsx
# this file: filet =  12.375
# Daily_Report_Scheduled_2019_01_28_033058.xlsx
# this file: filet =  9.53125
# Daily_Report_Scheduled_2019_01_29_033055.xlsx
# this file: filet =  7.65625
# Daily_Report_Scheduled_2019_01_30_033100.xlsx
# this file: filet =  9.578125
# Daily_Report_Scheduled_2019_01_31_033052.xlsx
# this file: filet =  8.078125
# Daily_Report_Scheduled_2019_02_01_033054.xlsx
# this file: filet =  7.984375
# Daily_Report_Scheduled_2019_02_02_033059.xlsx
# this file: filet =  9.71875
# Daily_Report_Scheduled_2019_02_03_033104.xlsx
# this file: filet =  12.234375
# Daily_Report_Scheduled_2019_02_04_033105.xlsx
# this file: filet =  11.46875
# Daily_Report_Scheduled_2019_02_05_033059.xlsx
# this file: filet =  9.9375
# Daily_Report_Scheduled_2019_02_06_033106.xlsx
# this file: filet =  9.484375
# Daily_Report_Scheduled_2019_02_07_033101.xlsx
# this file: filet =  8.46875
# Daily_Report_Scheduled_2019_02_08_033057.xlsx
# this file: filet =  8.6875
# Daily_Report_Scheduled_2019_02_09_033059.xlsx
# this file: filet =  10.78125
# Daily_Report_Scheduled_2019_02_10_033122.xlsx
# this file: filet =  15.875
# Daily_Report_Scheduled_2019_02_11_033102.xlsx
# this file: filet =  13.234375
# Daily_Report_Scheduled_2019_02_12_033106.xlsx
# this file: filet =  11.390625
# Daily_Report_Scheduled_2019_02_13_033103.xlsx
# this file: filet =  8.71875
# Daily_Report_Scheduled_2019_02_14_033105.xlsx
# this file: filet =  7.75
# Daily_Report_Scheduled_2019_02_15_033102.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2019_02_16_033104.xlsx
# this file: filet =  9.125
# Daily_Report_Scheduled_2019_02_17_033113.xlsx
# this file: filet =  12.46875
# Daily_Report_Scheduled_2019_02_18_033107.xlsx
# this file: filet =  9.515625
# Daily_Report_Scheduled_2019_02_19_033059.xlsx
# this file: filet =  7.75
# Daily_Report_Scheduled_2019_02_20_033105.xlsx
# this file: filet =  8.3125
# Daily_Report_Scheduled_2019_02_21_033101.xlsx
# this file: filet =  7.453125
# Daily_Report_Scheduled_2019_02_22_033057.xlsx
# this file: filet =  7.015625
# Daily_Report_Scheduled_2019_02_23_033058.xlsx
# this file: filet =  8.515625
# Daily_Report_Scheduled_2019_02_24_033119.xlsx
# this file: filet =  13.21875
# Daily_Report_Scheduled_2019_02_25_033106.xlsx
# this file: filet =  9.359375
# Daily_Report_Scheduled_2019_02_26_033100.xlsx
# this file: filet =  7.796875
# Daily_Report_Scheduled_2019_02_27_033058.xlsx
# this file: filet =  7.84375
# Daily_Report_Scheduled_2019_02_28_033059.xlsx
# this file: filet =  6.921875
# Daily_Report_Scheduled_2019_03_01_033053.xlsx
# this file: filet =  6.5625
# Daily_Report_Scheduled_2019_03_02_033102.xlsx
# this file: filet =  11.3125
# Daily_Report_Scheduled_2019_03_03_033109.xlsx
# this file: filet =  11.46875
# Daily_Report_Scheduled_2019_03_04_033107.xlsx
# this file: filet =  9.453125
# Daily_Report_Scheduled_2019_03_05_033059.xlsx
# this file: filet =  7.4375
# Daily_Report_Scheduled_2019_03_06_033101.xlsx
# this file: filet =  8.265625
# Daily_Report_Scheduled_2019_03_07_033058.xlsx
# this file: filet =  7.84375
# Daily_Report_Scheduled_2019_03_08_033049.xlsx
# this file: filet =  6.8125
# Daily_Report_Scheduled_2019_03_09_033104.xlsx
# this file: filet =  8.796875
# Daily_Report_Scheduled_2019_03_10_033121.xlsx
# this file: filet =  12.109375
# Daily_Report_Scheduled_2019_03_11_033105.xlsx
# this file: filet =  10.265625
# Daily_Report_Scheduled_2019_03_12_033056.xlsx
# this file: filet =  8.421875
# Daily_Report_Scheduled_2019_03_13_033053.xlsx
# this file: filet =  8.40625
# Daily_Report_Scheduled_2019_03_14_033059.xlsx
# this file: filet =  6.984375
# Daily_Report_Scheduled_2019_03_15_033054.xlsx
# this file: filet =  6.453125
# Daily_Report_Scheduled_2019_03_16_033059.xlsx
# this file: filet =  8.375
# Daily_Report_Scheduled_2019_03_17_033114.xlsx
# this file: filet =  12.4375
# Daily_Report_Scheduled_2019_03_18_033109.xlsx
# this file: filet =  10.296875
# Daily_Report_Scheduled_2019_03_19_033055.xlsx
# this file: filet =  7.953125
# Daily_Report_Scheduled_2019_03_20_033056.xlsx
# this file: filet =  11.6875
# Daily_Report_Scheduled_2019_03_21_033059.xlsx
# this file: filet =  8.0
# Daily_Report_Scheduled_2019_03_22_033053.xlsx
# this file: filet =  7.734375
# Daily_Report_Scheduled_2019_03_23_033100.xlsx
# this file: filet =  9.28125
# Daily_Report_Scheduled_2019_03_24_033113.xlsx
# this file: filet =  12.28125
# Daily_Report_Scheduled_2019_03_25_033105.xlsx
# this file: filet =  9.9375
# Daily_Report_Scheduled_2019_03_26_033105.xlsx
# this file: filet =  8.1875
# Daily_Report_Scheduled_2019_03_27_033108.xlsx
# this file: filet =  8.53125
# Daily_Report_Scheduled_2019_03_28_033101.xlsx
# this file: filet =  7.25
# Daily_Report_Scheduled_2019_03_29_033057.xlsx
# this file: filet =  6.703125
# Daily_Report_Scheduled_2019_03_30_033107.xlsx
# this file: filet =  8.65625
# Daily_Report_Scheduled_2019_03_31_033114.xlsx
# this file: filet =  12.75
# Daily_Report_Scheduled_2019_04_01_033107.xlsx
# this file: filet =  10.53125
# Daily_Report_Scheduled_2019_04_02_033100.xlsx
# this file: filet =  8.140625
# Daily_Report_Scheduled_2019_04_03_033056.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2019_04_04_033057.xlsx
# this file: filet =  8.5
# Daily_Report_Scheduled_2019_04_05_033053.xlsx
# this file: filet =  7.578125
# Daily_Report_Scheduled_2019_04_06_033101.xlsx
# this file: filet =  8.671875
# Daily_Report_Scheduled_2019_04_07_033116.xlsx
# this file: filet =  12.640625
# Daily_Report_Scheduled_2019_04_08_033102.xlsx
# this file: filet =  14.375
# Daily_Report_Scheduled_2019_04_09_033055.xlsx
# this file: filet =  7.703125
# Daily_Report_Scheduled_2019_04_10_033100.xlsx
# this file: filet =  8.25
# Daily_Report_Scheduled_2019_04_11_033052.xlsx
# this file: filet =  7.640625
# Daily_Report_Scheduled_2019_04_12_033049.xlsx
# this file: filet =  7.046875
# Daily_Report_Scheduled_2019_04_13_033100.xlsx
# this file: filet =  8.296875
# Daily_Report_Scheduled_2019_04_14_033103.xlsx
# this file: filet =  11.78125
# Daily_Report_Scheduled_2019_04_15_033108.xlsx
# this file: filet =  10.109375
# Daily_Report_Scheduled_2019_04_16_033055.xlsx
# this file: filet =  8.046875
# Daily_Report_Scheduled_2019_04_17_033046.xlsx
# this file: filet =  8.40625
# Daily_Report_Scheduled_2019_04_18_033053.xlsx
# this file: filet =  7.203125
# Daily_Report_Scheduled_2019_04_19_033057.xlsx
# this file: filet =  6.96875
# Daily_Report_Scheduled_2019_04_20_033106.xlsx
# this file: filet =  13.90625
# Daily_Report_Scheduled_2019_04_21_033111.xlsx
# this file: filet =  14.65625
# Daily_Report_Scheduled_2019_04_22_033100.xlsx
# this file: filet =  11.5
# Daily_Report_Scheduled_2019_04_23_033032.xlsx
# this file: filet =  0.875
# Daily_Report_Scheduled_2019_04_24_033043.xlsx
# this file: filet =  7.265625
# Daily_Report_Scheduled_2019_04_25_033049.xlsx
# this file: filet =  8.9375
# Daily_Report_Scheduled_2019_04_26_033055.xlsx
# this file: filet =  9.234375
# Daily_Report_Scheduled_2019_04_27_033057.xlsx
# this file: filet =  9.84375
# Daily_Report_Scheduled_2019_04_28_033105.xlsx
# this file: filet =  15.609375
# Daily_Report_Scheduled_2019_04_29_033108.xlsx
# this file: filet =  16.96875
# Daily_Report_Scheduled_2019_04_30_033058.xlsx
# this file: filet =  8.546875
# Daily_Report_Scheduled_2019_05_01_033049.xlsx
# this file: filet =  10.328125
# Daily_Report_Scheduled_2019_05_02_033047.xlsx
# this file: filet =  11.5
# Daily_Report_Scheduled_2019_05_03_033055.xlsx
# this file: filet =  8.5
# Daily_Report_Scheduled_2019_05_04_033100.xlsx
# this file: filet =  9.59375
# Daily_Report_Scheduled_2019_05_05_033105.xlsx
# this file: filet =  13.609375
# Daily_Report_Scheduled_2019_05_06_033106.xlsx
# this file: filet =  12.640625
# Daily_Report_Scheduled_2019_05_07_033051.xlsx
# this file: filet =  9.15625
# Daily_Report_Scheduled_2019_05_08_033049.xlsx
# this file: filet =  9.3125
# Daily_Report_Scheduled_2019_05_09_033049.xlsx
# this file: filet =  8.703125
# Daily_Report_Scheduled_2019_05_10_033051.xlsx
# this file: filet =  9.296875
# Daily_Report_Scheduled_2019_05_11_033054.xlsx
# this file: filet =  9.71875
# Daily_Report_Scheduled_2019_05_12_033102.xlsx
# this file: filet =  14.390625
# Daily_Report_Scheduled_2019_05_13_033102.xlsx
# this file: filet =  12.09375
# Daily_Report_Scheduled_2019_05_14_033050.xlsx
# this file: filet =  9.265625
# Daily_Report_Scheduled_2019_05_15_033054.xlsx
# this file: filet =  11.171875
# Daily_Report_Scheduled_2019_05_16_033048.xlsx
# this file: filet =  9.171875
# Daily_Report_Scheduled_2019_05_17_033044.xlsx
# this file: filet =  9.75
# Daily_Report_Scheduled_2019_05_18_033057.xlsx
# this file: filet =  8.84375
# Daily_Report_Scheduled_2019_05_19_033107.xlsx
# this file: filet =  12.90625
# Daily_Report_Scheduled_2019_05_20_033053.xlsx
# this file: filet =  10.125
# Daily_Report_Scheduled_2019_05_21_033045.xlsx
# this file: filet =  12.65625
# Daily_Report_Scheduled_2019_05_22_033051.xlsx
# this file: filet =  7.53125
# Daily_Report_Scheduled_2019_05_23_033044.xlsx
# this file: filet =  6.734375
# Daily_Report_Scheduled_2019_05_24_033045.xlsx
# this file: filet =  6.578125
# Daily_Report_Scheduled_2019_05_25_033057.xlsx
# this file: filet =  9.0625
# Daily_Report_Scheduled_2019_05_26_033113.xlsx
# this file: filet =  12.78125
# Daily_Report_Scheduled_2019_05_27_033108.xlsx
# this file: filet =  10.171875
# Daily_Report_Scheduled_2019_05_28_033056.xlsx
# this file: filet =  7.5
# Daily_Report_Scheduled_2019_05_29_033049.xlsx
# this file: filet =  6.96875
# Daily_Report_Scheduled_2019_05_30_033051.xlsx
# this file: filet =  7.84375
# Daily_Report_Scheduled_2019_05_31_033055.xlsx
# this file: filet =  7.34375
# Daily_Report_Scheduled_2019_06_01_033058.xlsx
# this file: filet =  8.921875
# Daily_Report_Scheduled_2019_06_02_033104.xlsx
# this file: filet =  11.875
# Daily_Report_Scheduled_2019_06_03_033103.xlsx
# this file: filet =  11.984375
# Daily_Report_Scheduled_2019_06_04_033056.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2019_06_05_033052.xlsx
# this file: filet =  8.71875
# Daily_Report_Scheduled_2019_06_06_033052.xlsx
# this file: filet =  7.78125
# Daily_Report_Scheduled_2019_06_07_033050.xlsx
# this file: filet =  7.40625
# Daily_Report_Scheduled_2019_06_08_033053.xlsx
# this file: filet =  8.5625
# Daily_Report_Scheduled_2019_06_09_033105.xlsx
# this file: filet =  12.734375
# Daily_Report_Scheduled_2019_06_10_033103.xlsx
# this file: filet =  10.6875
# Daily_Report_Scheduled_2019_06_11_033049.xlsx
# this file: filet =  8.203125
# Daily_Report_Scheduled_2019_06_12_033053.xlsx
# this file: filet =  13.265625
# Daily_Report_Scheduled_2019_06_13_033052.xlsx
# this file: filet =  8.34375
# Daily_Report_Scheduled_2019_06_14_033046.xlsx
# this file: filet =  7.125
# Daily_Report_Scheduled_2019_06_15_033052.xlsx
# this file: filet =  8.875
# Daily_Report_Scheduled_2019_06_16_033108.xlsx
# this file: filet =  13.109375
# Daily_Report_Scheduled_2019_06_17_033102.xlsx
# this file: filet =  10.5625
# Daily_Report_Scheduled_2019_06_18_033053.xlsx
# this file: filet =  7.53125
# Daily_Report_Scheduled_2019_06_19_033050.xlsx
# this file: filet =  8.015625
# Daily_Report_Scheduled_2019_06_20_033058.xlsx
# this file: filet =  7.796875
# Daily_Report_Scheduled_2019_06_21_033053.xlsx
# this file: filet =  7.203125
# Daily_Report_Scheduled_2019_06_22_033106.xlsx
# this file: filet =  8.96875
# Daily_Report_Scheduled_2019_06_23_033115.xlsx
# this file: filet =  12.484375
# Daily_Report_Scheduled_2019_06_24_033108.xlsx
# this file: filet =  10.734375
# Daily_Report_Scheduled_2019_06_25_033056.xlsx
# this file: filet =  8.203125
# Daily_Report_Scheduled_2019_06_26_033054.xlsx
# this file: filet =  8.359375
# Daily_Report_Scheduled_2019_06_27_033057.xlsx
# this file: filet =  10.03125
# Daily_Report_Scheduled_2019_06_28_033052.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2019_06_29_033106.xlsx
# this file: filet =  12.4375
# Daily_Report_Scheduled_2019_06_30_033117.xlsx
# this file: filet =  13.734375
# Daily_Report_Scheduled_2019_07_01_033059.xlsx
# this file: filet =  10.96875
# Daily_Report_Scheduled_2019_07_02_033101.xlsx
# this file: filet =  8.515625
# Daily_Report_Scheduled_2019_07_03_033055.xlsx
# this file: filet =  9.09375
# Daily_Report_Scheduled_2019_07_04_033051.xlsx
# this file: filet =  7.59375
# Daily_Report_Scheduled_2019_07_05_033048.xlsx
# this file: filet =  6.796875
# Daily_Report_Scheduled_2019_07_06_033055.xlsx
# this file: filet =  12.828125
# Daily_Report_Scheduled_2019_07_07_033107.xlsx
# this file: filet =  12.984375
# Daily_Report_Scheduled_2019_07_08_033103.xlsx
# this file: filet =  10.03125
# Daily_Report_Scheduled_2019_07_09_033051.xlsx
# this file: filet =  7.4375
# Daily_Report_Scheduled_2019_07_10_033058.xlsx
# this file: filet =  8.359375
# Daily_Report_Scheduled_2019_07_11_033051.xlsx
# this file: filet =  8.203125
# Daily_Report_Scheduled_2019_07_12_033049.xlsx
# this file: filet =  7.796875
# Daily_Report_Scheduled_2019_07_13_033100.xlsx
# this file: filet =  10.359375
# Daily_Report_Scheduled_2019_07_14_033106.xlsx
# this file: filet =  16.078125
# Daily_Report_Scheduled_2019_07_15_033059.xlsx
# this file: filet =  10.578125
# Daily_Report_Scheduled_2019_07_16_033054.xlsx
# this file: filet =  7.84375
# Daily_Report_Scheduled_2019_07_17_033059.xlsx
# this file: filet =  8.546875
# Daily_Report_Scheduled_2019_07_18_033053.xlsx
# this file: filet =  8.296875
# Daily_Report_Scheduled_2019_07_19_033050.xlsx
# this file: filet =  6.734375
# Daily_Report_Scheduled_2019_07_20_033056.xlsx
# this file: filet =  7.9375
# Daily_Report_Scheduled_2019_07_21_033106.xlsx
# this file: filet =  11.71875
# Daily_Report_Scheduled_2019_07_22_033101.xlsx
# this file: filet =  10.25
# Daily_Report_Scheduled_2019_07_23_033055.xlsx
# this file: filet =  8.640625
# Daily_Report_Scheduled_2019_07_24_033048.xlsx
# this file: filet =  9.03125
# Daily_Report_Scheduled_2019_07_25_033057.xlsx
# this file: filet =  7.484375
# Daily_Report_Scheduled_2019_07_26_033051.xlsx
# this file: filet =  7.078125
# Daily_Report_Scheduled_2019_07_27_033101.xlsx
# this file: filet =  8.53125
# Daily_Report_Scheduled_2019_07_28_033110.xlsx
# this file: filet =  11.40625
# Daily_Report_Scheduled_2019_07_29_033059.xlsx
# this file: filet =  14.984375
# Daily_Report_Scheduled_2019_07_30_033056.xlsx
# this file: filet =  7.453125
# Daily_Report_Scheduled_2019_07_31_033053.xlsx
# this file: filet =  9.53125
# Daily_Report_Scheduled_2019_08_01_033109.xlsx
# this file: filet =  9.046875
# Daily_Report_Scheduled_2019_08_02_033056.xlsx
# this file: filet =  9.25
# Daily_Report_Scheduled_2019_08_03_033058.xlsx
# this file: filet =  9.203125
# Daily_Report_Scheduled_2019_08_04_033109.xlsx
# this file: filet =  12.53125
# Daily_Report_Scheduled_2019_08_05_033101.xlsx
# this file: filet =  10.75
# Daily_Report_Scheduled_2019_08_06_033051.xlsx
# this file: filet =  7.265625
# Daily_Report_Scheduled_2019_08_07_033056.xlsx
# this file: filet =  8.59375
# Daily_Report_Scheduled_2019_08_08_033042.xlsx
# this file: filet =  7.96875
# Daily_Report_Scheduled_2019_08_09_033044.xlsx
# this file: filet =  6.96875
# Daily_Report_Scheduled_2019_08_10_033055.xlsx
# this file: filet =  9.84375
# Daily_Report_Scheduled_2019_08_11_033059.xlsx
# this file: filet =  14.203125
# Daily_Report_Scheduled_2019_08_12_033101.xlsx
# this file: filet =  10.578125
# Daily_Report_Scheduled_2019_08_13_033052.xlsx
# this file: filet =  7.890625
# Daily_Report_Scheduled_2019_08_14_033050.xlsx
# this file: filet =  8.109375
# Daily_Report_Scheduled_2019_08_15_033047.xlsx
# this file: filet =  7.265625
# Daily_Report_Scheduled_2019_08_16_033051.xlsx
# this file: filet =  6.75
# Daily_Report_Scheduled_2019_08_17_033053.xlsx
# this file: filet =  8.0
# Daily_Report_Scheduled_2019_08_18_033108.xlsx
# this file: filet =  12.015625
# Daily_Report_Scheduled_2019_08_19_033100.xlsx
# this file: filet =  9.078125
# Daily_Report_Scheduled_2019_08_20_033048.xlsx
# this file: filet =  6.90625
# Daily_Report_Scheduled_2019_08_21_033054.xlsx
# this file: filet =  8.140625
# Daily_Report_Scheduled_2019_08_22_033054.xlsx
# this file: filet =  6.75
# Daily_Report_Scheduled_2019_08_23_033053.xlsx
# this file: filet =  6.59375
# Daily_Report_Scheduled_2019_08_24_033056.xlsx
# this file: filet =  8.890625
# Daily_Report_Scheduled_2019_08_25_033106.xlsx
# this file: filet =  17.390625
# Daily_Report_Scheduled_2019_08_26_033103.xlsx
# this file: filet =  10.359375
# Daily_Report_Scheduled_2019_08_27_033052.xlsx
# this file: filet =  7.515625
# Daily_Report_Scheduled_2019_08_28_033053.xlsx
# this file: filet =  7.1875
# Daily_Report_Scheduled_2019_08_29_033054.xlsx
# this file: filet =  8.578125
# Daily_Report_Scheduled_2019_08_30_033052.xlsx
# this file: filet =  6.984375
# Daily_Report_Scheduled_2019_08_31_033059.xlsx
# this file: filet =  9.09375
# Daily_Report_Scheduled_2019_09_01_033113.xlsx
# this file: filet =  19.328125
# Daily_Report_Scheduled_2019_09_02_033108.xlsx
# this file: filet =  10.296875
# Daily_Report_Scheduled_2019_09_03_033053.xlsx
# this file: filet =  7.875
# Daily_Report_Scheduled_2019_09_04_033102.xlsx
# this file: filet =  9.421875
# Daily_Report_Scheduled_2019_09_05_033057.xlsx
# this file: filet =  11.578125
# Daily_Report_Scheduled_2019_09_06_033053.xlsx
# this file: filet =  8.515625
# Daily_Report_Scheduled_2019_09_07_033101.xlsx
# this file: filet =  8.453125
# Daily_Report_Scheduled_2019_09_08_033107.xlsx
# this file: filet =  14.34375
# Daily_Report_Scheduled_2019_09_09_033107.xlsx
# this file: filet =  13.171875
# Daily_Report_Scheduled_2019_09_10_033059.xlsx
# this file: filet =  9.78125
# Daily_Report_Scheduled_2019_09_11_033101.xlsx
# this file: filet =  9.859375
# Daily_Report_Scheduled_2019_09_12_033051.xlsx
# this file: filet =  7.609375
# Daily_Report_Scheduled_2019_09_13_033048.xlsx
# this file: filet =  7.625
# Daily_Report_Scheduled_2019_09_14_033052.xlsx
# this file: filet =  9.96875
# Daily_Report_Scheduled_2019_09_15_033059.xlsx
# this file: filet =  13.125
# Daily_Report_Scheduled_2019_09_16_033103.xlsx
# this file: filet =  10.90625
# Daily_Report_Scheduled_2019_09_17_033052.xlsx
# this file: filet =  8.78125
# Daily_Report_Scheduled_2019_09_18_033100.xlsx
# this file: filet =  9.53125
# Daily_Report_Scheduled_2019_09_19_033055.xlsx
# this file: filet =  8.328125
# Daily_Report_Scheduled_2019_09_20_033056.xlsx
# this file: filet =  13.9375
# Daily_Report_Scheduled_2019_09_21_033103.xlsx
# this file: filet =  13.03125
# Daily_Report_Scheduled_2019_09_22_033107.xlsx
# this file: filet =  14.375
# Daily_Report_Scheduled_2019_09_23_033102.xlsx
# this file: filet =  10.4375
# Daily_Report_Scheduled_2019_09_24_033058.xlsx
# this file: filet =  7.640625
# Daily_Report_Scheduled_2019_09_25_033057.xlsx
# this file: filet =  9.4375
# Daily_Report_Scheduled_2019_09_26_033103.xlsx
# this file: filet =  7.90625
# Daily_Report_Scheduled_2019_09_27_033105.xlsx
# this file: filet =  7.296875
# Daily_Report_Scheduled_2019_09_28_033103.xlsx
# this file: filet =  9.375
# Daily_Report_Scheduled_2019_09_29_033115.xlsx
# this file: filet =  13.28125
# Daily_Report_Scheduled_2019_09_30_033110.xlsx
# this file: filet =  11.4375
# Daily_Report_Scheduled_2019_10_01_033055.xlsx
# this file: filet =  9.0
# Daily_Report_Scheduled_2019_10_02_033101.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2019_10_03_033056.xlsx
# this file: filet =  8.78125
# Daily_Report_Scheduled_2019_10_04_033053.xlsx
# this file: filet =  7.140625
# Daily_Report_Scheduled_2019_10_05_033106.xlsx
# this file: filet =  9.96875
# Daily_Report_Scheduled_2019_10_06_033114.xlsx
# this file: filet =  13.03125
# Daily_Report_Scheduled_2019_10_07_033113.xlsx
# this file: filet =  10.515625
# Daily_Report_Scheduled_2019_10_08_033104.xlsx
# this file: filet =  8.8125
# Daily_Report_Scheduled_2019_10_09_033101.xlsx
# this file: filet =  9.046875
# Daily_Report_Scheduled_2019_10_10_033102.xlsx
# this file: filet =  8.921875
# Daily_Report_Scheduled_2019_10_11_033101.xlsx
# this file: filet =  7.015625
# Daily_Report_Scheduled_2019_10_12_033104.xlsx
# this file: filet =  9.109375
# Daily_Report_Scheduled_2019_10_13_033120.xlsx
# this file: filet =  12.5
# Daily_Report_Scheduled_2019_10_14_033117.xlsx
# this file: filet =  11.015625
# Daily_Report_Scheduled_2019_10_15_033102.xlsx
# this file: filet =  8.8125
# Daily_Report_Scheduled_2019_10_16_033115.xlsx
# this file: filet =  15.109375
# Daily_Report_Scheduled_2019_10_17_033059.xlsx
# this file: filet =  9.203125
# Daily_Report_Scheduled_2019_10_18_033104.xlsx
# this file: filet =  6.96875
# Daily_Report_Scheduled_2019_10_19_033107.xlsx
# this file: filet =  8.4375
# Daily_Report_Scheduled_2019_10_20_033121.xlsx
# this file: filet =  12.328125
# Daily_Report_Scheduled_2019_10_21_033117.xlsx
# this file: filet =  10.21875
# Daily_Report_Scheduled_2019_10_22_233059.xlsx
# this file: filet =  7.75
# Daily_Report_Scheduled_2019_10_23_033104.xlsx
# this file: filet =  8.578125
# Daily_Report_Scheduled_2019_10_24_001556.xlsx
# this file: filet =  7.515625
# Daily_Report_Scheduled_2019_10_24_033050.xlsx
# this file: filet =  7.921875
# Daily_Report_Scheduled_2019_10_24_233103.xlsx
# this file: filet =  9.328125
# Daily_Report_Scheduled_2019_10_25_033050.xlsx
# this file: filet =  8.25
# Daily_Report_Scheduled_2019_10_25_233109.xlsx
# this file: filet =  14.28125
# Daily_Report_Scheduled_2019_10_26_033055.xlsx
# this file: filet =  10.75
# Daily_Report_Scheduled_2019_10_26_233117.xlsx
# this file: filet =  10.984375
# Daily_Report_Scheduled_2019_10_27_033110.xlsx
# this file: filet =  12.234375
# Daily_Report_Scheduled_2019_10_27_233114.xlsx
# this file: filet =  9.625
# Daily_Report_Scheduled_2019_10_28_033110.xlsx
# this file: filet =  11.984375
# Daily_Report_Scheduled_2019_10_28_233109.xlsx
# this file: filet =  9.078125
# Daily_Report_Scheduled_2019_10_29_033146.xlsx
# this file: filet =  8.484375
# Daily_Report_Scheduled_2019_10_30_033012.xlsx
# this file: filet =  0.0
# Daily_Report_Scheduled_2019_10_31_033034.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2019_11_01_033114.xlsx
# this file: filet =  8.28125
# Daily_Report_Scheduled_2019_11_02_033055.xlsx
# this file: filet =  9.203125
# Daily_Report_Scheduled_2019_11_03_033126.xlsx
# this file: filet =  13.0
# Daily_Report_Scheduled_2019_11_04_033108.xlsx
# this file: filet =  10.6875
# Daily_Report_Scheduled_2019_11_05_033108.xlsx
# this file: filet =  9.59375
# Daily_Report_Scheduled_2019_11_06_033111.xlsx
# this file: filet =  10.03125
# Daily_Report_Scheduled_2019_11_07_033139.xlsx
# this file: filet =  8.625
# Daily_Report_Scheduled_2019_11_08_033059.xlsx
# this file: filet =  13.3125
# Daily_Report_Scheduled_2019_11_09_033104.xlsx
# this file: filet =  9.9375
# Daily_Report_Scheduled_2019_11_10_033116.xlsx
# this file: filet =  15.609375
# Daily_Report_Scheduled_2019_11_11_033126.xlsx
# this file: filet =  14.796875
# Daily_Report_Scheduled_2019_11_12_033107.xlsx
# this file: filet =  12.0
# Daily_Report_Scheduled_2019_11_13_033108.xlsx
# this file: filet =  10.484375
# Daily_Report_Scheduled_2019_11_14_033117.xlsx
# this file: filet =  9.359375
# Daily_Report_Scheduled_2019_11_15_033117.xlsx
# this file: filet =  6.8125
# Daily_Report_Scheduled_2019_11_16_033111.xlsx
# this file: filet =  10.765625
# Daily_Report_Scheduled_2019_11_17_033117.xlsx
# this file: filet =  24.875
# Daily_Report_Scheduled_2019_11_18_033121.xlsx
# this file: filet =  20.6875
# Daily_Report_Scheduled_2019_11_19_033119.xlsx
# this file: filet =  15.625
# Daily_Report_Scheduled_2019_11_20_033014.xlsx
# this file: filet =  0.015625
# Daily_Report_Scheduled_2019_11_21_033037.xlsx
# this file: filet =  0.046875
# Daily_Report_Scheduled_2019_11_22_033107.xlsx
# this file: filet =  8.46875
# Daily_Report_Scheduled_2019_11_23_033114.xlsx
# this file: filet =  12.625
# Daily_Report_Scheduled_2019_11_24_033125.xlsx
# this file: filet =  23.765625
# Daily_Report_Scheduled_2019_11_25_033114.xlsx
# this file: filet =  15.921875
# Daily_Report_Scheduled_2019_11_26_033118.xlsx
# this file: filet =  10.0625
# Daily_Report_Scheduled_2019_11_27_033112.xlsx
# this file: filet =  9.46875
# Daily_Report_Scheduled_2019_11_28_033108.xlsx
# this file: filet =  9.4375
# Daily_Report_Scheduled_2019_11_29_033104.xlsx
# this file: filet =  7.890625
# Daily_Report_Scheduled_2019_11_30_033120.xlsx
# this file: filet =  9.890625
# Daily_Report_Scheduled_2019_12_01_033132.xlsx
# this file: filet =  13.828125
# Daily_Report_Scheduled_2019_12_02_033118.xlsx
# this file: filet =  15.71875
# Daily_Report_Scheduled_2019_12_03_033105.xlsx
# this file: filet =  12.921875
# Daily_Report_Scheduled_2019_12_04_033125.xlsx
# this file: filet =  11.046875
# Daily_Report_Scheduled_2019_12_05_033113.xlsx
# this file: filet =  9.796875
# Daily_Report_Scheduled_2019_12_06_033100.xlsx
# this file: filet =  13.921875
# Daily_Report_Scheduled_2019_12_07_033120.xlsx
# this file: filet =  9.640625
# Daily_Report_Scheduled_2019_12_08_033137.xlsx
# this file: filet =  12.890625
# Daily_Report_Scheduled_2019_12_09_033124.xlsx
# this file: filet =  10.75
# Daily_Report_Scheduled_2019_12_10_033126.xlsx
# this file: filet =  9.203125
# Daily_Report_Scheduled_2019_12_11_033139.xlsx
# this file: filet =  10.515625
# Daily_Report_Scheduled_2019_12_12_033119.xlsx
# this file: filet =  9.46875
# Daily_Report_Scheduled_2019_12_13_033118.xlsx
# this file: filet =  9.171875
# Daily_Report_Scheduled_2019_12_14_033133.xlsx
# this file: filet =  11.078125
# Daily_Report_Scheduled_2019_12_15_033138.xlsx
# this file: filet =  15.328125
# Daily_Report_Scheduled_2019_12_16_033137.xlsx
# this file: filet =  15.203125
# Daily_Report_Scheduled_2019_12_17_033127.xlsx
# this file: filet =  12.921875
# Daily_Report_Scheduled_2019_12_18_033130.xlsx
# this file: filet =  11.0625
# Daily_Report_Scheduled_2019_12_19_033110.xlsx
# this file: filet =  10.015625
# Daily_Report_Scheduled_2019_12_20_033126.xlsx
# this file: filet =  10.265625
# Daily_Report_Scheduled_2019_12_21_033141.xlsx
# this file: filet =  16.0625
# Daily_Report_Scheduled_2019_12_22_033144.xlsx
# this file: filet =  17.875
# Daily_Report_Scheduled_2019_12_23_033142.xlsx
# this file: filet =  21.71875
# Daily_Report_Scheduled_2019_12_24_033141.xlsx
# this file: filet =  28.09375
# Daily_Report_Scheduled_2019_12_25_033145.xlsx
# this file: filet =  20.03125
# Daily_Report_Scheduled_2019_12_26_033053.xlsx
# this file: filet =  5.265625
# Daily_Report_Scheduled_2019_12_27_033017.xlsx
# this file: filet =  0.0
# Daily_Report_Scheduled_2019_12_28_033015.xlsx
# this file: filet =  0.0
# Daily_Report_Scheduled_2019_12_29_033058.xlsx
# this file: filet =  7.6875
# Daily_Report_Scheduled_2019_12_30_033103.xlsx
# this file: filet =  9.234375
# Daily_Report_Scheduled_2019_12_31_033105.xlsx
# this file: filet =  14.515625
# Daily_Report_Scheduled_2020_01_01_033103.xlsx
# this file: filet =  12.40625
# Daily_Report_Scheduled_2020_01_02_033059.xlsx
# this file: filet =  13.046875
# Daily_Report_Scheduled_2020_01_03_033032.xlsx
# this file: filet =  0.421875
# Daily_Report_Scheduled_2020_01_04_033101.xlsx
# this file: filet =  10.734375
# Daily_Report_Scheduled_2020_01_05_033122.xlsx
# this file: filet =  13.953125
# Daily_Report_Scheduled_2020_01_06_033116.xlsx
# this file: filet =  10.9375
# Daily_Report_Scheduled_2020_01_07_033118.xlsx
# this file: filet =  9.5625
# Daily_Report_Scheduled_2020_01_08_033116.xlsx
# this file: filet =  9.9375
# Daily_Report_Scheduled_2020_01_09_033105.xlsx
# this file: filet =  8.203125
# Daily_Report_Scheduled_2020_01_10_033101.xlsx
# this file: filet =  7.421875
# Daily_Report_Scheduled_2020_01_11_033114.xlsx
# this file: filet =  9.625
# Daily_Report_Scheduled_2020_01_12_033126.xlsx
# this file: filet =  13.28125
# Daily_Report_Scheduled_2020_01_13_033116.xlsx
# this file: filet =  11.09375
# Daily_Report_Scheduled_2020_01_14_033115.xlsx
# this file: filet =  8.765625
# Daily_Report_Scheduled_2020_01_15_033119.xlsx
# this file: filet =  9.0
# Daily_Report_Scheduled_2020_01_16_033103.xlsx
# this file: filet =  7.8125
# Daily_Report_Scheduled_2020_01_17_033059.xlsx
# this file: filet =  7.359375
# Daily_Report_Scheduled_2020_01_18_033111.xlsx
# this file: filet =  9.15625
# Daily_Report_Scheduled_2020_01_19_033127.xlsx
# this file: filet =  13.546875
# Daily_Report_Scheduled_2020_01_20_033110.xlsx
# this file: filet =  10.484375
# Daily_Report_Scheduled_2020_01_21_033107.xlsx
# this file: filet =  8.46875
# Daily_Report_Scheduled_2020_01_22_033107.xlsx
# this file: filet =  8.859375
# Daily_Report_Scheduled_2020_01_23_033100.xlsx
# this file: filet =  7.5625
# Daily_Report_Scheduled_2020_01_24_033056.xlsx
# this file: filet =  6.375
# Daily_Report_Scheduled_2020_01_25_033100.xlsx
# this file: filet =  8.578125
# Daily_Report_Scheduled_2020_01_26_033118.xlsx
# this file: filet =  13.984375
# Daily_Report_Scheduled_2020_01_27_033105.xlsx
# this file: filet =  13.796875
# Daily_Report_Scheduled_2020_01_28_033106.xlsx
# this file: filet =  11.4375
# Daily_Report_Scheduled_2020_01_29_033111.xlsx
# this file: filet =  14.015625
# Daily_Report_Scheduled_2020_01_30_033103.xlsx
# this file: filet =  10.25
# Total run time =  7721.9375

# %%
route_dict = {route_columns[0]:Route_ID_route, route_columns[1]:Branch_ID_route, route_columns[2]:FL_Name_route,
                        route_columns[3]:Start_Date_of_Route_route, route_columns[4]:Start_Time_of_Route_route,
                        route_columns[5]:End_Time_of_Route_route, route_columns[6]:Break_Duration_mins_route, 
                        route_columns[7]:Percentage_Shift_Time_used_route, route_columns[8]:Percentage_Van_Weight_used_route,
                        route_columns[9]:Percentage_Ambient_Capacity_Used_route,
                        route_columns[10]:Percentage_Chilled_Capacity_Used_route,
                        route_columns[11]:Percentage_Frozen_Capacity_Used_route,
                        route_columns[12]:Percentage_Total_Crate_capacity_Used_route,
                        route_columns[13]:Planned_total_Route_time_route, route_columns[14]:Planned_Total_Wait_time_mins_route,
                        route_columns[15]:Planned_total_Mileage_route, route_columns[16]:Planned_Total_Driving_time_route,
                        route_columns[17]:Number_Orders_route, route_columns[18]:Van_Type_route,
                        route_columns[19]:Loaded_Ambient_Crates_route, route_columns[20]:Loaded_Chilled_Crates_route,
                        route_columns[21]:Loaded_Frozen_Crates_route, route_columns[22]:Loaded_Kgs_route,
                        route_columns[23]:Loaded_Total_Crates_route, route_columns[24]:Total_Dwell_Time_route,
                        route_columns[25]:Shift_Start_Time_route, route_columns[26]:Shift_End_Time_route,
                        route_columns[27]:Total_Shift_Hours_route, route_columns[28]:Total_Shift_Time_Spent_at_FL_route,
                        route_columns[29]:MPO_route, route_columns[30]:HPO_route}

order_dict = {order_columns[0]:Route_ID_order,
order_columns[1]:Order_Sequence_order,           
order_columns[2]:Order_ID_order,                
order_columns[3]:Order_Type_order,             
order_columns[4]:Order_Delivery_Date_order,                   
order_columns[5]:Time_Window_Start_order,                  
order_columns[6]:Time_Window_End_order,               
order_columns[7]:Planned_Arrival_Time_order,                  
order_columns[8]:Planned_Departure_Time_order,                 
order_columns[9]:Break_Duration_Minutes_order,                 
order_columns[10]:Wait_Time_since_Prev_Stop_Minutes_order,         
order_columns[11]:Post_Code_order,      
order_columns[12]:X_Coord_order,               
order_columns[13]:Y_Coord_order,               
order_columns[14]:MPO_order,
order_columns[15]:Driving_Mins_Per_Order_order,                
order_columns[16]:Ambient_order,               
order_columns[17]:Chilled_order,            
order_columns[18]:Frozen_order,                  
order_columns[19]:Total_order,                
order_columns[20]:Kg_order,               
order_columns[21]:Dwell_Time_order}

# %%
route_df = pd.DataFrame.from_dict(route_dict, orient='index')
route_df = route_df.transpose()

order_df = pd.DataFrame.from_dict(order_dict, orient='index')
order_df = order_df.transpose()

# %%
order_df.to_csv(r'C:\Users\benfl\OneDrive - Flexible Power Systems Ltd\Documents\Python Scripts\Waitrose Collation\collated_data_all\collated_order_data_all_07022020.csv')

# %%
route_df.to_csv(r'C:\Users\benfl\OneDrive - Flexible Power Systems Ltd\Documents\Python Scripts\Waitrose Collation\collated_data_all\collated_route_data_all_07022020.csv')
